# %%
import json
from pathlib import Path
from urllib.parse import urlparse

from tqdm import tqdm
import requests
from bs4 import BeautifulSoup

import pandas as pd

# %%
from time import sleep
from requests.exceptions import HTTPError
import re
from multiprocessing import Pool

# %%
pd.set_option('max_colwidth', 100) # 50 by default

# %% [markdown]
# ### Get validation results file

# %%
VALIDATION_RESULTS_FILE = '/home/jupyter/data/url_validation_results.json'

# %%
valid_results = []

with open(VALIDATION_RESULTS_FILE) as f:
    for line in f:
        valid_results.append(json.loads(line))
    
print(valid_results[:10])
# Out:
# [{'url': 'https://habr.com/ru/company/wrike/blog/506928/', 'is_valid': True, 'domain': 'habr.com'}, {'url': 'https://vimeo.com/91371852', 'is_valid': True, 'domain': 'vimeo.com'}, {'url': 'https://www.youtube.com/watch?v=vvdLLbhxwDA', 'is_valid': True, 'domain': 'youtube.com'}, {'url': 'https://www.youtube.com/watch?v=l5aw6LHt9iI', 'is_valid': True, 'domain': 'youtube.com'}, {'url': 'https://habr.com/ru/post/193844/', 'is_valid': True, 'domain': 'habr.com'}, {'url': 'https://vimeo.com/4085044', 'is_valid': True, 'domain': 'vimeo.com'}, {'url': 'https://www.youtube.com/watch?v=U4kyT-wwEi0', 'is_valid': True, 'domain': 'youtube.com'}, {'url': 'https://www.youtube.com/watch?v=-UuXFqXp7P4', 'is_valid': True, 'domain': 'youtube.com'}, {'url': 'https://vimeo.com/33717000', 'is_valid': True, 'domain': 'vimeo.com'}, {'url': 'https://www.youtube.com/watch?v=wW9trOm303g', 'is_valid': True, 'domain': 'youtube.com'}]

# %%
def filter_urls(valid_results, domain, is_valid=True):
    results = filter(lambda x: x['is_valid'] is is_valid and x['domain'] == domain, 
                     valid_results)
    urls = map(lambda x: x['url'], results)
    return list(urls)

# %%
def clean_views_count(raw_views_count):
    units_map = {'k': 1000}
    views_count = str(raw_views_count).lower().strip()
    
    if views_count[-1] in units_map:
        unit = views_count[-1]
        num = views_count[:-1]
        
        views_count = float(re.sub('\D', '', num))
        decimal_seps = re.findall(r'[\.,]', num)
        
        if len(decimal_seps) > 0:
            decimal_sep = decimal_seps[0]
            decimal_pos = len(num) - num.find(decimal_sep) - 1
        else:
            decimal_pos = 0
        
        views_count = int(views_count * units_map[unit] / (10**decimal_pos))
    else:
        views_count = int(re.sub('\D', '', views_count))
    
    return views_count

# %% [markdown]
# ### Parse sites

# %% [markdown]
# **habr.com**

# %%
habr_urls = filter_urls(valid_results, 'habr.com')
habr_urls[:10]
# Out:
# ['https://habr.com/ru/company/wrike/blog/506928/',
#  'https://habr.com/ru/post/193844/',
#  'https://habr.com/ru/post/496612/',
#  'https://habr.com/ru/post/481488/',
#  'https://habr.com/ru/post/491974/',
#  'https://habr.com/ru/company/toshibarus/blog/462185/',
#  'https://habr.com/ru/post/461037/',
#  'https://habr.com/ru/post/450807/',
#  'https://habr.com/ru/company/tuturu/blog/474688/',
#  'https://habr.com/ru/company/dcmiran/blog/504414/']

# %%
def get_habr_views_count(url):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36'}
    req = requests.get(url, headers=headers)
    
    try:
        req.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    html_text = req.text
    soup = BeautifulSoup(html_text, 'lxml')
    
    try:
        views_count = soup.find('span', class_="post-stats__views-count").text
    except AttributeError as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in habr_urls[:5]:
    parse_results = get_habr_views_count(url)
# Out:
# {'url': 'https://habr.com/ru/company/wrike/blog/506928/', 'is_parsed': True, 'raw_views_count': '528', 'views_count': 528}
# {'url': 'https://habr.com/ru/post/193844/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/496612/', 'is_parsed': True, 'raw_views_count': '89,5k', 'views_count': 89500}
# {'url': 'https://habr.com/ru/post/481488/', 'is_parsed': True, 'raw_views_count': '47,4k', 'views_count': 47400}
# {'url': 'https://habr.com/ru/post/491974/', 'is_parsed': True, 'raw_views_count': '5528k', 'views_count': 5528000}
# CPU times: user 910 ms, sys: 43 ms, total: 953 ms
# Wall time: 6.4 s

# %%
# %%time
parse_results = list(map(get_habr_views_count, habr_urls[:5]))
# Out:
# {'url': 'https://habr.com/ru/company/wrike/blog/506928/', 'is_parsed': True, 'raw_views_count': '528', 'views_count': 528}
# {'url': 'https://habr.com/ru/post/193844/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/496612/', 'is_parsed': True, 'raw_views_count': '89,5k', 'views_count': 89500}
# {'url': 'https://habr.com/ru/post/481488/', 'is_parsed': True, 'raw_views_count': '47,4k', 'views_count': 47400}
# {'url': 'https://habr.com/ru/post/491974/', 'is_parsed': True, 'raw_views_count': '5528k', 'views_count': 5528000}
# CPU times: user 924 ms, sys: 13 ms, total: 937 ms
# Wall time: 8.06 s

# %%
# %%time
with Pool() as P:
    parse_results = P.map(get_habr_views_count, habr_urls)
# Out:
# {'url': 'https://habr.com/ru/company/wrike/blog/506928/', 'is_parsed': True, 'raw_views_count': '528', 'views_count': 528}
# {'url': 'https://habr.com/ru/post/459947/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/193844/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/496612/', 'is_parsed': True, 'raw_views_count': '89,5k', 'views_count': 89500}
# {'url': 'https://habr.com/ru/company/habr/blog/503774/', 'is_parsed': True, 'raw_views_count': '14,1k', 'views_count': 14100}
# {'url': 'https://habr.com/ru/post/772408/', 'is_parsed': False, 'error_code': '404_not_found'}{'url': 'https://habr.com/ru/post/494512/', 'is_parsed': True, 'raw_views_count': '86,5k', 'views_count': 86500}
# {'url': 'https://habr.com/ru/post/480162/', 'is_parsed': True, 'raw_views_count': '47,8k', 'views_count': 47800}
#
# {'url': 'https://habr.com/ru/company/skyeng/blog/487764/', 'is_parsed': True, 'raw_views_count': '126k', 'views_count': 126000}
# {'url': 'https://habr.com/ru/post/481488/', 'is_parsed': True, 'raw_views_count': '47,4k', 'views_count': 47400}
# {'url': 'https://habr.com/ru/post/471628/', 'is_parsed': True, 'raw_views_count': '90,4k', 'views_count': 90400}
# {'url': 'https://habr.com/ru/company/mosigra/blog/469421/', 'is_parsed': True, 'raw_views_count': '64,6k', 'views_count': 64600}
# {'url': 'https://habr.com/ru/post/507138/', 'is_parsed': True, 'raw_views_count': '1,9k', 'views_count': 1900}
# {'url': 'https://habr.com/ru/post/491974/', 'is_parsed': True, 'raw_views_count': '5528k', 'views_count': 5528000}
# {'url': 'https://habr.com/ru/post/491796/', 'is_parsed': True, 'raw_views_count': '89,4k', 'views_count': 89400}
# {'url': 'https://habr.com/ru/post/459980/', 'is_parsed': True, 'raw_views_count': '69,9k', 'views_count': 69900}
# {'url': 'https://habr.com/ru/post/483880/', 'is_parsed': True, 'raw_views_count': '81,2k', 'views_count': 81200}
# {'url': 'https://habr.com/ru/company/pvs-studio/blog/507110/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/post/416912/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/epam_systems/blog/507000/', 'is_parsed': True, 'raw_views_count': '14,1k', 'views_count': 14100}
# {'url': 'https://habr.com/ru/post/461745/', 'is_parsed': True, 'raw_views_count': '118k', 'views_count': 118000}
# {'url': 'https://habr.com/ru/post/489254/', 'is_parsed': True, 'raw_views_count': '112k', 'views_count': 112000}
# {'url': 'https://habr.com/ru/company/toshibarus/blog/462185/', 'is_parsed': True, 'raw_views_count': '121k', 'views_count': 121000}
# {'url': 'https://habr.com/ru/post/490420/', 'is_parsed': True, 'raw_views_count': '30,5k', 'views_count': 30500}
# {'url': 'https://habr.com/ru/post/506417/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/467607/', 'is_parsed': True, 'raw_views_count': '86k', 'views_count': 86000}
# {'url': 'https://habr.com/ru/post/459240/', 'is_parsed': True, 'raw_views_count': '143k', 'views_count': 143000}
# {'url': 'https://habr.com/ru/post/480348/', 'is_parsed': True, 'raw_views_count': '46,6k', 'views_count': 46600}
# {'url': 'https://habr.com/ru/post/075708/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/skyeng/blog/465291/', 'is_parsed': True, 'raw_views_count': '73,5k', 'views_count': 73500}
# {'url': 'https://habr.com/ru/post/473028/', 'is_parsed': True, 'raw_views_count': '90,4k', 'views_count': 90400}
# {'url': 'https://habr.com/ru/company/yandex/blog/507028/', 'is_parsed': True, 'raw_views_count': '6,8k', 'views_count': 6800}
# {'url': 'https://habr.com/ru/post/461037/', 'is_parsed': True, 'raw_views_count': '62k', 'views_count': 62000}
# {'url': 'https://habr.com/ru/post/450807/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/507160/', 'is_parsed': True, 'raw_views_count': '13,4k', 'views_count': 13400}
# {'url': 'https://habr.com/ru/company/oleg-bunin/blog/461829/', 'is_parsed': True, 'raw_views_count': '87,2k', 'views_count': 87200}
# {'url': 'https://habr.com/ru/post/498260/', 'is_parsed': True, 'raw_views_count': '115k', 'views_count': 115000}
# {'url': 'https://habr.com/ru/post/466151/', 'is_parsed': True, 'raw_views_count': '101k', 'views_count': 101000}
# {'url': 'https://habr.com/ru/company/tuturu/blog/474688/', 'is_parsed': True, 'raw_views_count': '43,6k', 'views_count': 43600}
# {'url': 'https://habr.com/ru/post/481822/', 'is_parsed': True, 'raw_views_count': '60,7k', 'views_count': 60700}
# {'url': 'https://habr.com/ru/post/480510/', 'is_parsed': True, 'raw_views_count': '152k', 'views_count': 152000}
# {'url': 'https://habr.com/ru/company/digital-ecosystems/blog/157007/', 'is_parsed': True, 'raw_views_count': '41,9k', 'views_count': 41900}
# {'url': 'https://habr.com/ru/post/492410/', 'is_parsed': True, 'raw_views_count': '61,1k', 'views_count': 61100}
# {'url': 'https://habr.com/ru/post/417827/', 'is_parsed': True, 'raw_views_count': '7k', 'views_count': 7000}
# {'url': 'https://habr.com/ru/post/460655/', 'is_parsed': True, 'raw_views_count': '61,9k', 'views_count': 61900}
# {'url': 'https://habr.com/ru/company/pocketbook/blog/808714/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/dcmiran/blog/504414/', 'is_parsed': True, 'raw_views_count': '54,8k', 'views_count': 54800}
# {'url': 'https://habr.com/ru/company/southbridge/blog/468377/', 'is_parsed': True, 'raw_views_count': '127k', 'views_count': 127000}
# {'url': 'https://habr.com/ru/post/484436/', 'is_parsed': True, 'raw_views_count': '124k', 'views_count': 124000}
# {'url': 'https://habr.com/ru/company/leader-id/blog/507042/', 'is_parsed': True, 'raw_views_count': '7,4k', 'views_count': 7400}
# {'url': 'https://habr.com/ru/post/459710/', 'is_parsed': True, 'raw_views_count': '68k', 'views_count': 68000}
# {'url': 'https://habr.com/ru/post/487646/', 'is_parsed': True, 'raw_views_count': '42,4k', 'views_count': 42400}
# {'url': 'https://habr.com/ru/post/477900/', 'is_parsed': True, 'raw_views_count': '38,2k', 'views_count': 38200}
# {'url': 'https://habr.com/ru/company/dataline/blog/507176/', 'is_parsed': True, 'raw_views_count': '841', 'views_count': 841}
# {'url': 'https://habr.com/ru/post/466941/', 'is_parsed': True, 'raw_views_count': '142k', 'views_count': 142000}
# {'url': 'https://habr.com/ru/post/507074/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/post/489492/', 'is_parsed': True, 'raw_views_count': '90,4k', 'views_count': 90400}
# {'url': 'https://habr.com/ru/company/badoo/blog/458792/', 'is_parsed': True, 'raw_views_count': '131k', 'views_count': 131000}
# {'url': 'https://habr.com/ru/post/497956/', 'is_parsed': True, 'raw_views_count': '228k', 'views_count': 228000}
# {'url': 'https://habr.com/ru/post/459894/', 'is_parsed': True, 'raw_views_count': '63,9k', 'views_count': 63900}
# {'url': 'https://habr.com/ru/post/478844/', 'is_parsed': True, 'raw_views_count': '117k', 'views_count': 117000}
# {'url': 'https://habr.com/ru/post/463165/', 'is_parsed': True, 'raw_views_count': '134k', 'views_count': 134000}
# {'url': 'https://habr.com/ru/post/457790/', 'is_parsed': True, 'raw_views_count': '52,3k', 'views_count': 52300}
# {'url': 'https://habr.com/ru/post/482826/', 'is_parsed': True, 'raw_views_count': '40,2k', 'views_count': 40200}
# {'url': 'https://habr.com/ru/post/464603/', 'is_parsed': True, 'raw_views_count': '169k', 'views_count': 169000}
# {'url': 'https://habr.com/ru/post/473144/', 'is_parsed': True, 'raw_views_count': '52,8k', 'views_count': 52800}
# {'url': 'https://habr.com/ru/post/465029/', 'is_parsed': True, 'raw_views_count': '89k', 'views_count': 89000}
# {'url': 'https://habr.com/ru/company/mailru/blog/456862/', 'is_parsed': True, 'raw_views_count': '110k', 'views_count': 110000}
# {'url': 'https://habr.com/ru/post/503062/', 'is_parsed': True, 'raw_views_count': '119k', 'views_count': 119000}
# {'url': 'https://habr.com/ru/company/ruvds/blog/502068/', 'is_parsed': True, 'raw_views_count': '88,2k', 'views_count': 88200}
# {'url': 'https://habr.com/ru/company/skyeng/blog/865794/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/tuturu/blog/495832/', 'is_parsed': True, 'raw_views_count': '76,4k', 'views_count': 76400}
# {'url': 'https://habr.com/ru/post/458492/', 'is_parsed': True, 'raw_views_count': '55,3k', 'views_count': 55300}
# {'url': 'https://habr.com/ru/post/194766/', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://habr.com/ru/post/471908/', 'is_parsed': True, 'raw_views_count': '50,6k', 'views_count': 50600}
# {'url': 'https://habr.com/ru/company/hh/blog/507048/', 'is_parsed': True, 'raw_views_count': '3,6k', 'views_count': 3600}
# {'url': 'https://habr.com/ru/post/497114/', 'is_parsed': True, 'raw_views_count': '126k', 'views_count': 126000}
# {'url': 'https://habr.com/ru/post/485010/', 'is_parsed': True, 'raw_views_count': '87,4k', 'views_count': 87400}
# {'url': 'https://habr.com/ru/company/spbifmo/blog/507172/', 'is_parsed': True, 'raw_views_count': '2,3k', 'views_count': 2300}
# {'url': 'https://habr.com/ru/post/505302/', 'is_parsed': True, 'raw_views_count': '43,5k', 'views_count': 43500}
# {'url': 'https://habr.com/ru/post/473034/', 'is_parsed': True, 'raw_views_count': '88,5k', 'views_count': 88500}
# {'url': 'https://habr.com/ru/post/475058/', 'is_parsed': True, 'raw_views_count': '23,1k', 'views_count': 23100}
# {'url': 'https://habr.com/ru/post/465689/', 'is_parsed': True, 'raw_views_count': '61,3k', 'views_count': 61300}
# {'url': 'https://habr.com/ru/post/503038/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/post/468909/', 'is_parsed': True, 'raw_views_count': '179k', 'views_count': 179000}
# {'url': 'https://habr.com/ru/post/482806/', 'is_parsed': True, 'raw_views_count': '78,3k', 'views_count': 78300}
# {'url': 'https://habr.com/ru/post/491614/', 'is_parsed': True, 'raw_views_count': '94,7k', 'views_count': 94700}
# {'url': 'https://habr.com/ru/company/cognitivepilot/blog/508694/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/reactos/blog/480238/', 'is_parsed': True, 'raw_views_count': '28,8k', 'views_count': 28800}
# {'url': 'https://habr.com/ru/company/domclick/blog/507072/', 'is_parsed': True, 'raw_views_count': '4k', 'views_count': 4000}
# {'url': 'https://habr.com/ru/company/habr/blog/478090/', 'is_parsed': True, 'raw_views_count': '11,9k', 'views_count': 11900}
# {'url': 'https://habr.com/ru/company/digitalrightscenter/blog/464785/', 'is_parsed': True, 'raw_views_count': '64,2k', 'views_count': 64200}
# {'url': 'https://habr.com/ru/post/486372/', 'is_parsed': True, 'raw_views_count': '120k', 'views_count': 120000}
# {'url': 'https://habr.com/ru/post/505932/', 'is_parsed': True, 'raw_views_count': '79,1k', 'views_count': 79100}
# {'url': 'https://habr.com/ru/post/494548/', 'is_parsed': True, 'raw_views_count': '48,3k', 'views_count': 48300}
# {'url': 'https://habr.com/ru/post/554365/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/469275/', 'is_parsed': True, 'raw_views_count': '67,4k', 'views_count': 67400}
# {'url': 'https://habr.com/ru/company/cognitivepilot/blog/499440/', 'is_parsed': True, 'raw_views_count': '27,3k', 'views_count': 27300}
# {'url': 'https://habr.com/ru/post/465367/', 'is_parsed': True, 'raw_views_count': '57,7k', 'views_count': 57700}
# {'url': 'https://habr.com/ru/company/it-grad/blog/507114/', 'is_parsed': True, 'raw_views_count': '24,9k', 'views_count': 24900}
# {'url': 'https://habr.com/ru/company/pvs-studio/blog/507162/', 'is_parsed': True, 'raw_views_count': '8,2k', 'views_count': 8200}
# {'url': 'https://habr.com/ru/post/467733/', 'is_parsed': True, 'raw_views_count': '99k', 'views_count': 99000}
# {'url': 'https://habr.com/ru/post/463441/', 'is_parsed': True, 'raw_views_count': '73,3k', 'views_count': 73300}
# {'url': 'https://habr.com/ru/post/470734/', 'is_parsed': True, 'raw_views_count': '70,9k', 'views_count': 70900}
# {'url': 'https://habr.com/ru/post/486492/', 'is_parsed': True, 'raw_views_count': '41,9k', 'views_count': 41900}
# {'url': 'https://habr.com/ru/post/469435/', 'is_parsed': True, 'raw_views_count': '41,2k', 'views_count': 41200}
# {'url': 'https://habr.com/ru/post/466355/', 'is_parsed': True, 'raw_views_count': '56k', 'views_count': 56000}
# {'url': 'https://habr.com/ru/post/495662/', 'is_parsed': True, 'raw_views_count': '40k', 'views_count': 40000}
# {'url': 'https://habr.com/ru/post/468653/', 'is_parsed': True, 'raw_views_count': '110k', 'views_count': 110000}
# {'url': 'https://habr.com/ru/post/482182/', 'is_parsed': True, 'raw_views_count': '43,2k', 'views_count': 43200}
# {'url': 'https://habr.com/ru/post/486746/', 'is_parsed': True, 'raw_views_count': '26,3k', 'views_count': 26300}
# {'url': 'https://habr.com/ru/post/480956/', 'is_parsed': True, 'raw_views_count': '116k', 'views_count': 116000}
# {'url': 'https://habr.com/ru/post/505240/', 'is_parsed': True, 'raw_views_count': '121k', 'views_count': 121000}
# {'url': 'https://habr.com/ru/post/248412/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/ruvds/blog/534289/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/475432/', 'is_parsed': True, 'raw_views_count': '72,7k', 'views_count': 72700}
# {'url': 'https://habr.com/ru/post/472970/', 'is_parsed': True, 'raw_views_count': '40,1k', 'views_count': 40100}
# {'url': 'https://habr.com/ru/company/yandex/blog/487078/', 'is_parsed': True, 'raw_views_count': '67,9k', 'views_count': 67900}
# {'url': 'https://habr.com/ru/post/471032/', 'is_parsed': True, 'raw_views_count': '63,4k', 'views_count': 63400}
# {'url': 'https://habr.com/ru/company/intel/blog/507002/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/post/476034/', 'is_parsed': True, 'raw_views_count': '186k', 'views_count': 186000}
# {'url': 'https://habr.com/ru/post/460925/', 'is_parsed': True, 'raw_views_count': '51,4k', 'views_count': 51400}
# {'url': 'https://habr.com/ru/post/496752/', 'is_parsed': True, 'raw_views_count': '40,2k', 'views_count': 40200}
# {'url': 'https://habr.com/ru/company/vasexperts/blog/507106/', 'is_parsed': True, 'raw_views_count': '5,6k', 'views_count': 5600}
# {'url': 'https://habr.com/ru/post/463957/', 'is_parsed': True, 'raw_views_count': '70k', 'views_count': 70000}
# {'url': 'https://habr.com/ru/company/JetBrains/blog/478866/', 'is_parsed': True, 'raw_views_count': '65,3k', 'views_count': 65300}
# {'url': 'https://habr.com/ru/post/506894/', 'is_parsed': True, 'raw_views_count': '13k', 'views_count': 13000}
# {'url': 'https://habr.com/ru/company/englishdom/blog/507128/', 'is_parsed': True, 'raw_views_count': '3k', 'views_count': 3000}
# {'url': 'https://habr.com/ru/post/493232/', 'is_parsed': True, 'raw_views_count': '91,8k', 'views_count': 91800}
# {'url': 'https://habr.com/ru/post/328497/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/oleg-bunin/blog/480136/', 'is_parsed': True, 'raw_views_count': '62,2k', 'views_count': 62200}
# {'url': 'https://habr.com/ru/company/redmadrobot/blog/507040/', 'is_parsed': True, 'raw_views_count': '3,7k', 'views_count': 3700}
# {'url': 'https://habr.com/ru/post/501044/', 'is_parsed': True, 'raw_views_count': '174k', 'views_count': 174000}
# {'url': 'https://habr.com/ru/post/662394/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/regionsoft/blog/500006/', 'is_parsed': True, 'raw_views_count': '4,8k', 'views_count': 4800}
# {'url': 'https://habr.com/ru/post/492524/', 'is_parsed': True, 'raw_views_count': '85,2k', 'views_count': 85200}
# {'url': 'https://habr.com/ru/company/tuturu/blog/486850/', 'is_parsed': True, 'raw_views_count': '78k', 'views_count': 78000}
# {'url': 'https://habr.com/ru/post/848477/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/tuturu/blog/482166/', 'is_parsed': True, 'raw_views_count': '34,6k', 'views_count': 34600}
# {'url': 'https://habr.com/ru/post/482352/', 'is_parsed': True, 'raw_views_count': '170k', 'views_count': 170000}
# {'url': 'https://habr.com/ru/post/459128/', 'is_parsed': True, 'raw_views_count': '78,4k', 'views_count': 78400}
# {'url': 'https://habr.com/ru/post/496600/', 'is_parsed': True, 'raw_views_count': '74,5k', 'views_count': 74500}
# {'url': 'https://habr.com/ru/post/456912/', 'is_parsed': True, 'raw_views_count': '124k', 'views_count': 124000}
# {'url': 'https://habr.com/ru/post/500832/', 'is_parsed': True, 'raw_views_count': '54,7k', 'views_count': 54700}
# {'url': 'https://habr.com/ru/post/478878/', 'is_parsed': True, 'raw_views_count': '63,6k', 'views_count': 63600}
# {'url': 'https://habr.com/ru/post/482778/', 'is_parsed': True, 'raw_views_count': '73,7k', 'views_count': 73700}
# {'url': 'https://habr.com/ru/company/analogbytes/blog/503552/', 'is_parsed': True, 'raw_views_count': '171k', 'views_count': 171000}
# {'url': 'https://habr.com/ru/post/468603/', 'is_parsed': True, 'raw_views_count': '160k', 'views_count': 160000}
# {'url': 'https://habr.com/ru/post/480204/', 'is_parsed': True, 'raw_views_count': '91,7k', 'views_count': 91700}
# {'url': 'https://habr.com/ru/company/roskomsvoboda/blog/480056/', 'is_parsed': True, 'raw_views_count': '77,7k', 'views_count': 77700}
# {'url': 'https://habr.com/ru/post/481710/', 'is_parsed': True, 'raw_views_count': '40,6k', 'views_count': 40600}
# {'url': 'https://habr.com/ru/post/463281/', 'is_parsed': True, 'raw_views_count': '35,7k', 'views_count': 35700}
# {'url': 'https://habr.com/ru/post/457686/', 'is_parsed': True, 'raw_views_count': '87,4k', 'views_count': 87400}
# {'url': 'https://habr.com/ru/post/500246/', 'is_parsed': True, 'raw_views_count': '29,1k', 'views_count': 29100}
# {'url': 'https://habr.com/ru/post/346148/', 'is_parsed': True, 'raw_views_count': '3,8k', 'views_count': 3800}
# {'url': 'https://habr.com/ru/post/468491/', 'is_parsed': True, 'raw_views_count': '60,3k', 'views_count': 60300}
# {'url': 'https://habr.com/ru/post/484944/', 'is_parsed': True, 'raw_views_count': '91,1k', 'views_count': 91100}
# {'url': 'https://habr.com/ru/post/501860/', 'is_parsed': True, 'raw_views_count': '37k', 'views_count': 37000}
# {'url': 'https://habr.com/ru/post/480040/', 'is_parsed': True, 'raw_views_count': '135k', 'views_count': 135000}
# {'url': 'https://habr.com/ru/post/489314/', 'is_parsed': True, 'raw_views_count': '74,5k', 'views_count': 74500}
# {'url': 'https://habr.com/ru/company/mosigra/blog/463773/', 'is_parsed': True, 'raw_views_count': '76,9k', 'views_count': 76900}
# {'url': 'https://habr.com/ru/post/498604/', 'is_parsed': True, 'raw_views_count': '75,3k', 'views_count': 75300}
# {'url': 'https://habr.com/ru/post/486456/', 'is_parsed': True, 'raw_views_count': '50,4k', 'views_count': 50400}
# {'url': 'https://habr.com/ru/post/471020/', 'is_parsed': True, 'raw_views_count': '42,1k', 'views_count': 42100}
# {'url': 'https://habr.com/ru/company/manychat/blog/507136/', 'is_parsed': True, 'raw_views_count': '8,6k', 'views_count': 8600}
# {'url': 'https://habr.com/ru/post/482110/', 'is_parsed': True, 'raw_views_count': '94,5k', 'views_count': 94500}
# {'url': 'https://habr.com/ru/company/habr/blog/488088/', 'is_parsed': True, 'raw_views_count': '81,3k', 'views_count': 81300}
# {'url': 'https://habr.com/ru/post/477136/', 'is_parsed': True, 'raw_views_count': '41,6k', 'views_count': 41600}
# {'url': 'https://habr.com/ru/post/507146/', 'is_parsed': True, 'raw_views_count': '2,1k', 'views_count': 2100}
# {'url': 'https://habr.com/ru/post/499314/', 'is_parsed': True, 'raw_views_count': '47k', 'views_count': 47000}{'url': 'https://habr.com/ru/post/490080/', 'is_parsed': True, 'raw_views_count': '53,3k', 'views_count': 53300}
#
# {'url': 'https://habr.com/ru/post/486326/', 'is_parsed': True, 'raw_views_count': '62,1k', 'views_count': 62100}
# {'url': 'https://habr.com/ru/post/007246/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/mailru/blog/507080/', 'is_parsed': True, 'raw_views_count': '1,5k', 'views_count': 1500}
# {'url': 'https://habr.com/ru/post/470337/', 'is_parsed': True, 'raw_views_count': '223k', 'views_count': 223000}
# {'url': 'https://habr.com/ru/post/488224/', 'is_parsed': True, 'raw_views_count': '81k', 'views_count': 81000}
# {'url': 'https://habr.com/ru/post/464621/', 'is_parsed': True, 'raw_views_count': '98,2k', 'views_count': 98200}
# {'url': 'https://habr.com/ru/post/504632/', 'is_parsed': True, 'raw_views_count': '42,3k', 'views_count': 42300}
# {'url': 'https://habr.com/ru/post/476434/', 'is_parsed': True, 'raw_views_count': '56,2k', 'views_count': 56200}
# {'url': 'https://habr.com/ru/post/473544/', 'is_parsed': True, 'raw_views_count': '108k', 'views_count': 108000}
# {'url': 'https://habr.com/ru/company/ruvds/blog/495124/', 'is_parsed': True, 'raw_views_count': '79,4k', 'views_count': 79400}
# {'url': 'https://habr.com/ru/company/dataart/blog/468073/', 'is_parsed': True, 'raw_views_count': '69,4k', 'views_count': 69400}
# {'url': 'https://habr.com/ru/post/498406/', 'is_parsed': True, 'raw_views_count': '89k', 'views_count': 89000}
# {'url': 'https://habr.com/ru/post/473666/', 'is_parsed': True, 'raw_views_count': '71k', 'views_count': 71000}
# {'url': 'https://habr.com/ru/post/486174/', 'is_parsed': True, 'raw_views_count': '168k', 'views_count': 168000}
# {'url': 'https://habr.com/ru/company/otus/blog/507104/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/company/tuturu/blog/474976/', 'is_parsed': True, 'raw_views_count': '44,1k', 'views_count': 44100}
# {'url': 'https://habr.com/ru/company/itsumma/blog/984126/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/503932/', 'is_parsed': True, 'raw_views_count': '108k', 'views_count': 108000}
# {'url': 'https://habr.com/ru/post/491288/', 'is_parsed': True, 'raw_views_count': '74,3k', 'views_count': 74300}
# {'url': 'https://habr.com/ru/post/458464/', 'is_parsed': True, 'raw_views_count': '49,9k', 'views_count': 49900}
# {'url': 'https://habr.com/ru/company/croc/blog/458440/', 'is_parsed': True, 'raw_views_count': '65,6k', 'views_count': 65600}
# {'url': 'https://habr.com/ru/post/459254/', 'is_parsed': True, 'raw_views_count': '76,2k', 'views_count': 76200}
# {'url': 'https://habr.com/ru/company/pm/blog/462479/', 'is_parsed': True, 'raw_views_count': '44,8k', 'views_count': 44800}
# {'url': 'https://habr.com/ru/company/tuturu/blog/495110/', 'is_parsed': True, 'raw_views_count': '45,4k', 'views_count': 45400}
# {'url': 'https://habr.com/ru/company/banzai/blog/506390/', 'is_parsed': True, 'raw_views_count': '815', 'views_count': 815}
# {'url': 'https://habr.com/ru/post/454078/', 'is_parsed': True, 'raw_views_count': '138k', 'views_count': 138000}
# {'url': 'https://habr.com/ru/post/507088/', 'is_parsed': True, 'raw_views_count': '6,9k', 'views_count': 6900}
# {'url': 'https://habr.com/ru/post/200375/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/solarsecurity/blog/502576/', 'is_parsed': True, 'raw_views_count': '69,2k', 'views_count': 69200}
# {'url': 'https://habr.com/ru/company/itelma/blog/505376/', 'is_parsed': True, 'raw_views_count': '11,2k', 'views_count': 11200}
# {'url': 'https://habr.com/ru/post/497602/', 'is_parsed': True, 'raw_views_count': '84k', 'views_count': 84000}
# {'url': 'https://habr.com/ru/post/500754/', 'is_parsed': True, 'raw_views_count': '163k', 'views_count': 163000}
# {'url': 'https://habr.com/ru/post/488592/', 'is_parsed': True, 'raw_views_count': '85,3k', 'views_count': 85300}
# {'url': 'https://habr.com/ru/post/477440/', 'is_parsed': True, 'raw_views_count': '65,9k', 'views_count': 65900}
# {'url': 'https://habr.com/ru/post/490620/', 'is_parsed': True, 'raw_views_count': '61,8k', 'views_count': 61800}
# {'url': 'https://habr.com/ru/post/487120/', 'is_parsed': True, 'raw_views_count': '87,4k', 'views_count': 87400}
# {'url': 'https://habr.com/ru/company/ruvds/blog/506778/', 'is_parsed': True, 'raw_views_count': '5,2k', 'views_count': 5200}
# {'url': 'https://habr.com/ru/post/506218/', 'is_parsed': True, 'raw_views_count': '51,6k', 'views_count': 51600}
# {'url': 'https://habr.com/ru/post/505576/', 'is_parsed': True, 'raw_views_count': '108k', 'views_count': 108000}
# {'url': 'https://habr.com/ru/post/477740/', 'is_parsed': True, 'raw_views_count': '33,3k', 'views_count': 33300}
# {'url': 'https://habr.com/ru/post/470561/', 'is_parsed': True, 'raw_views_count': '108k', 'views_count': 108000}
# {'url': 'https://habr.com/ru/post/448724/', 'is_parsed': True, 'raw_views_count': '7,7k', 'views_count': 7700}
# {'url': 'https://habr.com/ru/company/epam_systems/blog/483384/', 'is_parsed': True, 'raw_views_count': '143k', 'views_count': 143000}
# {'url': 'https://habr.com/ru/company/habr_career/blog/479702/', 'is_parsed': True, 'raw_views_count': '32,8k', 'views_count': 32800}
# {'url': 'https://habr.com/ru/post/480234/', 'is_parsed': True, 'raw_views_count': '36,7k', 'views_count': 36700}
# {'url': 'https://habr.com/ru/post/487290/', 'is_parsed': True, 'raw_views_count': '155k', 'views_count': 155000}
# {'url': 'https://habr.com/ru/post/485272/', 'is_parsed': True, 'raw_views_count': '35,7k', 'views_count': 35700}
# {'url': 'https://habr.com/ru/company/epam_systems/blog/507000/', 'is_parsed': True, 'raw_views_count': '14,1k', 'views_count': 14100}
# {'url': 'https://habr.com/ru/company/plesk/blog/507094/', 'is_parsed': True, 'raw_views_count': '3,5k', 'views_count': 3500}
# {'url': 'https://habr.com/ru/post/499394/', 'is_parsed': True, 'raw_views_count': '125k', 'views_count': 125000}
# {'url': 'https://habr.com/ru/company/otus/blog/506800/', 'is_parsed': True, 'raw_views_count': '1,3k', 'views_count': 1300}
# {'url': 'https://habr.com/ru/post/487116/', 'is_parsed': True, 'raw_views_count': '62,6k', 'views_count': 62600}
# {'url': 'https://habr.com/ru/company/misis/blog/507188/', 'is_parsed': True, 'raw_views_count': '11k', 'views_count': 11000}
# {'url': 'https://habr.com/ru/post/459262/', 'is_parsed': True, 'raw_views_count': '171k', 'views_count': 171000}
# {'url': 'https://habr.com/ru/post/505728/', 'is_parsed': True, 'raw_views_count': '7k', 'views_count': 7000}
# {'url': 'https://habr.com/ru/company/itsumma/blog/471518/', 'is_parsed': True, 'raw_views_count': '137k', 'views_count': 137000}
# {'url': 'https://habr.com/rf/post/506828/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/intel/blog/507002/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/company/mailru/blog/490790/', 'is_parsed': True, 'raw_views_count': '50,7k', 'views_count': 50700}
# {'url': 'https://habr.com/ru/company/ruvds/blog/507234/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/post/469893/', 'is_parsed': True, 'raw_views_count': '31,4k', 'views_count': 31400}
# {'url': 'https://habr.com/ru/company/pvs-studio/blog/507162/', 'is_parsed': True, 'raw_views_count': '8,2k', 'views_count': 8200}
# {'url': 'https://habr.com/ru/company/flant/blog/506848/', 'is_parsed': True, 'raw_views_count': '27k', 'views_count': 27000}
# {'url': 'https://habr.com/ru/post/494592/', 'is_parsed': True, 'raw_views_count': '20k', 'views_count': 20000}{'url': 'https://habr.com/ru/company/iticapital/blog/506926/', 'is_parsed': True, 'raw_views_count': '2,8k', 'views_count': 2800}
#
# {'url': 'https://habr.com/ru/post/506886/', 'is_parsed': True, 'raw_views_count': '1,7k', 'views_count': 1700}
# {'url': 'https://habr.com/ru/post/874730/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/463411/', 'is_parsed': True, 'raw_views_count': '83,9k', 'views_count': 83900}
# {'url': 'https://habr.com/ru/post/500926/', 'is_parsed': True, 'raw_views_count': '66,9k', 'views_count': 66900}
# {'url': 'https://habr.com/ru/company/dataart/blog/475646/', 'is_parsed': True, 'raw_views_count': '63,9k', 'views_count': 63900}
# {'url': 'https://habr.com/ru/company/lamptest/blog/458856/', 'is_parsed': True, 'raw_views_count': '212k', 'views_count': 212000}
# {'url': 'https://habr.com/ru/post/507116/', 'is_parsed': True, 'raw_views_count': '3,3k', 'views_count': 3300}
# {'url': 'https://habr.com/ru/post/503038/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/post/507078/', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://habr.com/ru/company/dataart/blog/507132/', 'is_parsed': True, 'raw_views_count': '5,5k', 'views_count': 5500}
# {'url': 'https://habr.com/ru/post/214546/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/tinkoff/blog/848879/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/top3dshop/blog/506986/', 'is_parsed': True, 'raw_views_count': '239', 'views_count': 239}
# {'url': 'https://habr.com/ru/post/506832/', 'is_parsed': True, 'raw_views_count': '22,8k', 'views_count': 22800}
# {'url': 'https://habr.com/ru/company/smartengines/blog/507006/', 'is_parsed': True, 'raw_views_count': '4,5k', 'views_count': 4500}
# {'url': 'https://habr.com/ru/company/phoenix_contact/blog/506936/', 'is_parsed': True, 'raw_views_count': '6,8k', 'views_count': 6800}
# {'url': 'https://habr.com/ru/post/476384/', 'is_parsed': True, 'raw_views_count': '39,3k', 'views_count': 39300}
# {'url': 'https://habr.com/ru/company/croccloudteam/blog/506968/', 'is_parsed': True, 'raw_views_count': '4,5k', 'views_count': 4500}
# {'url': 'https://habr.com/ru/post/485806/', 'is_parsed': True, 'raw_views_count': '309k', 'views_count': 309000}
# {'url': 'https://habr.com/ru/post/485532/', 'is_parsed': True, 'raw_views_count': '133k', 'views_count': 133000}
# {'url': 'https://habr.com/ru/post/485918/', 'is_parsed': True, 'raw_views_count': '71,5k', 'views_count': 71500}
# {'url': 'https://habr.com/ru/company/vdsina/blog/507016/', 'is_parsed': True, 'raw_views_count': '24,2k', 'views_count': 24200}
# {'url': 'https://habr.com/ru/company/habr/blog/469811/', 'is_parsed': True, 'raw_views_count': '38,8k', 'views_count': 38800}
# {'url': 'https://habr.com/ru/post/506694/', 'is_parsed': True, 'raw_views_count': '7,4k', 'views_count': 7400}
# {'url': 'https://habr.com/ru/company/ruvds/blog/505384/', 'is_parsed': True, 'raw_views_count': '88,9k', 'views_count': 88900}
# {'url': 'https://habr.com/ru/post/506896/', 'is_parsed': True, 'raw_views_count': '21,4k', 'views_count': 21400}
# {'url': 'https://habr.com/ru/post/464409/', 'is_parsed': True, 'raw_views_count': '62,7k', 'views_count': 62700}
# {'url': 'https://habr.com/ru/company/misis/blog/506908/', 'is_parsed': True, 'raw_views_count': '1,1k', 'views_count': 1100}
# {'url': 'https://habr.com/ru/post/507146/', 'is_parsed': True, 'raw_views_count': '2,1k', 'views_count': 2100}
# {'url': 'https://habr.com/ru/company/flant/blog/474436/', 'is_parsed': True, 'raw_views_count': '133k', 'views_count': 133000}
# {'url': 'https://habr.com/ru/post/483156/', 'is_parsed': True, 'raw_views_count': '67k', 'views_count': 67000}
# {'url': 'https://habr.com/ru/company/auriga/blog/505638/', 'is_parsed': True, 'raw_views_count': '732', 'views_count': 732}
# {'url': 'https://habr.com/ru/company/mailru/blog/507080/', 'is_parsed': True, 'raw_views_count': '1,5k', 'views_count': 1500}
# {'url': 'https://habr.com/ru/company/raiffeisenbank/blog/506310/', 'is_parsed': True, 'raw_views_count': '963', 'views_count': 963}
# {'url': 'https://habr.com/ru/post/506756/', 'is_parsed': True, 'raw_views_count': '1,9k', 'views_count': 1900}
# {'url': 'https://habr.com/ru/company/yandex/blog/480090/', 'is_parsed': True, 'raw_views_count': '94,4k', 'views_count': 94400}
# {'url': 'https://habr.com/ru/company/ua-hosting/blog/506838/', 'is_parsed': True, 'raw_views_count': '11,3k', 'views_count': 11300}
# {'url': 'https://habr.com/ru/post/507088/', 'is_parsed': True, 'raw_views_count': '6,9k', 'views_count': 6900}
# {'url': 'https://habr.com/ru/post/507142/', 'is_parsed': True, 'raw_views_count': '990', 'views_count': 990}
# {'url': 'https://habr.com/ru/post/490294/', 'is_parsed': True, 'raw_views_count': '136k', 'views_count': 136000}
# {'url': 'https://habr.com/ru/post/475468/', 'is_parsed': True, 'raw_views_count': '75,1k', 'views_count': 75100}
# {'url': 'https://habr.com/ru/post/507150/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/company/otus/blog/507148/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}{'url': 'https://habr.com/ru/company/zabbix/blog/507092/', 'is_parsed': True, 'raw_views_count': '961', 'views_count': 961}
#
# {'url': 'https://habr.com/ru/post/507150/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/post/495840/', 'is_parsed': True, 'raw_views_count': '7,4k', 'views_count': 7400}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/506868/', 'is_parsed': True, 'raw_views_count': '708', 'views_count': 708}
# {'url': 'https://habr.com/ru/post/434318/', 'is_parsed': True, 'raw_views_count': '55,1k', 'views_count': 55100}
# {'url': 'https://habr.com/ru/post/506580/', 'is_parsed': True, 'raw_views_count': '1,1k', 'views_count': 1100}{'url': 'https://habr.com/ru/company/domclick/blog/506802/', 'is_parsed': True, 'raw_views_count': '2,2k', 'views_count': 2200}
#
# {'url': 'https://habr.com/ru/company/npoechelon/blog/506940/', 'is_parsed': True, 'raw_views_count': '3,5k', 'views_count': 3500}
# {'url': 'https://habr.com/ru/company/alconost/blog/507260/', 'is_parsed': True, 'raw_views_count': '435', 'views_count': 435}
# {'url': 'https://habr.com/ru/post/506670/', 'is_parsed': True, 'raw_views_count': '3,5k', 'views_count': 3500}
# {'url': 'https://habr.com/ru/company/it-grad/blog/507114/', 'is_parsed': True, 'raw_views_count': '24,9k', 'views_count': 24900}
# {'url': 'https://habr.com/ru/company/englishdom/blog/507128/', 'is_parsed': True, 'raw_views_count': '3k', 'views_count': 3000}
# {'url': 'https://habr.com/ru/company/otus/blog/507224/', 'is_parsed': True, 'raw_views_count': '362', 'views_count': 362}
# {'url': 'https://habr.com/ru/company/mailru/blog/503102/', 'is_parsed': True, 'raw_views_count': '3,5k', 'views_count': 3500}
# {'url': 'https://habr.com/ru/post/507090/', 'is_parsed': True, 'raw_views_count': '647', 'views_count': 647}
# {'url': 'https://habr.com/ru/post/507256/', 'is_parsed': True, 'raw_views_count': '1,7k', 'views_count': 1700}
# {'url': 'https://habr.com/ru/company/otus/blog/507270/', 'is_parsed': True, 'raw_views_count': '655', 'views_count': 655}
# {'url': 'https://habr.com/ru/post/506722/', 'is_parsed': True, 'raw_views_count': '3,7k', 'views_count': 3700}
# {'url': 'https://habr.com/ru/company/ua-hosting/blog/488816/', 'is_parsed': True, 'raw_views_count': '72,8k', 'views_count': 72800}
# {'url': 'https://habr.com/ru/company/vasexperts/blog/507106/', 'is_parsed': True, 'raw_views_count': '5,6k', 'views_count': 5600}
# {'url': 'https://habr.com/ru/company/lanit/blog/505820/', 'is_parsed': True, 'raw_views_count': '11,9k', 'views_count': 11900}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/506888/', 'is_parsed': True, 'raw_views_count': '3,6k', 'views_count': 3600}
# {'url': 'https://habr.com/ru/company/snom/blog/506998/', 'is_parsed': True, 'raw_views_count': '873', 'views_count': 873}
# {'url': 'https://habr.com/ru/company/microsoft/blog/503462/', 'is_parsed': True, 'raw_views_count': '6k', 'views_count': 6000}
# {'url': 'https://habr.com/ru/post/506870/', 'is_parsed': True, 'raw_views_count': '4,4k', 'views_count': 4400}
# {'url': 'https://habr.com/ru/post/507086/', 'is_parsed': True, 'raw_views_count': '1,3k', 'views_count': 1300}
# {'url': 'https://habr.com/ru/company/wrike/blog/506952/', 'is_parsed': True, 'raw_views_count': '2,8k', 'views_count': 2800}
# {'url': 'https://habr.com/ru/company/JetBrains-education/blog/506416/', 'is_parsed': True, 'raw_views_count': '770', 'views_count': 770}
# {'url': 'https://habr.com/ru/company/ruvds/blog/506774/', 'is_parsed': True, 'raw_views_count': '11,2k', 'views_count': 11200}
# {'url': 'https://habr.com/ru/post/506842/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/company/piter/blog/507212/', 'is_parsed': True, 'raw_views_count': '1,1k', 'views_count': 1100}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/507196/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/company/piter/blog/506872/', 'is_parsed': True, 'raw_views_count': '2k', 'views_count': 2000}
# {'url': 'https://habr.com/ru/company/domclick/blog/507072/', 'is_parsed': True, 'raw_views_count': '4k', 'views_count': 4000}
# {'url': 'https://habr.com/ru/compahy/skillfactory/blog/507024/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/507166/', 'is_parsed': True, 'raw_views_count': '509', 'views_count': 509}
# {'url': 'https://habr.com/ru/post/507280/', 'is_parsed': True, 'raw_views_count': '79,5k', 'views_count': 79500}
# {'url': 'https://habr.com/ru/company/habr_career/blog/507258/', 'is_parsed': True, 'raw_views_count': '9,3k', 'views_count': 9300}
# {'url': 'https://habr.com/ru/company/regionsoft/blog/500006/', 'is_parsed': True, 'raw_views_count': '4,8k', 'views_count': 4800}
# {'url': 'https://habr.com/ru/post/491098/', 'is_parsed': True, 'raw_views_count': '2,5k', 'views_count': 2500}
# {'url': 'https://habr.com/ru/company/dataline/blog/507176/', 'is_parsed': True, 'raw_views_count': '841', 'views_count': 841}
# {'url': 'https://habr.com/ru/company/ruvds/blog/506776/', 'is_parsed': True, 'raw_views_count': '15,7k', 'views_count': 15700}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/507264/', 'is_parsed': True, 'raw_views_count': '15,9k', 'views_count': 15900}
# {'url': 'https://habr.com/ru/post/507238/', 'is_parsed': True, 'raw_views_count': '304', 'views_count': 304}
# {'url': 'https://habr.com/ru/company/dataart/blog/507132/', 'is_parsed': True, 'raw_views_count': '5,5k', 'views_count': 5500}
# {'url': 'https://habr.com/ru/company/spbifmo/blog/507172/', 'is_parsed': True, 'raw_views_count': '2,3k', 'views_count': 2300}
# {'url': 'https://habr.com/ru/company/yandex/blog/507026/', 'is_parsed': True, 'raw_views_count': '9,7k', 'views_count': 9700}
# {'url': 'https://habr.com/ru/post/507254/', 'is_parsed': True, 'raw_views_count': '2,6k', 'views_count': 2600}
# {'url': 'https://habr.com/ru/post/506938/', 'is_parsed': True, 'raw_views_count': '5,6k', 'views_count': 5600}
# {'url': 'https://habr.com/ru/company/misis/blog/507188/', 'is_parsed': True, 'raw_views_count': '11k', 'views_count': 11000}
# {'url': 'https://habr.com/ru/company/jetinfosystems/blog/506750/', 'is_parsed': True, 'raw_views_count': '7,8k', 'views_count': 7800}
# {'url': 'https://habr.com/ru/post/507044/', 'is_parsed': True, 'raw_views_count': '7,8k', 'views_count': 7800}
# {'url': 'https://habr.com/ru/company/leroy_merlin/blog/507062/', 'is_parsed': True, 'raw_views_count': '5,5k', 'views_count': 5500}
# {'url': 'https://habr.com/ru/company/kingston_technology/blog/506250/', 'is_parsed': True, 'raw_views_count': '8k', 'views_count': 8000}
# {'url': 'https://habr.com/ru/post/507226/', 'is_parsed': True, 'raw_views_count': '1,9k', 'views_count': 1900}
# {'url': 'https://habr.com/ru/company/dbtc/blog/506930/', 'is_parsed': True, 'raw_views_count': '2,2k', 'views_count': 2200}
# {'url': 'https://habr.com/ru/company/redmadrobot/blog/507040/', 'is_parsed': True, 'raw_views_count': '3,7k', 'views_count': 3700}
# {'url': 'https://habr.com/ru/company/avito/blog/506784/', 'is_parsed': True, 'raw_views_count': '870', 'views_count': 870}
# {'url': 'https://habr.com/ru/post/507236/', 'is_parsed': True, 'raw_views_count': '2,3k', 'views_count': 2300}
# {'url': 'https://habr.com/ru/post/469521/', 'is_parsed': True, 'raw_views_count': '101k', 'views_count': 101000}
# {'url': 'https://habr.com/ru/company/microsoft/blog/506654/', 'is_parsed': True, 'raw_views_count': '2,1k', 'views_count': 2100}
# {'url': 'https://habr.com/ru/company/lenovo/blog/507020/', 'is_parsed': True, 'raw_views_count': '969', 'views_count': 969}
# {'url': 'https://habr.com/ru/company/alconost/blog/506944/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/post/506718/', 'is_parsed': True, 'raw_views_count': '34,5k', 'views_count': 34500}
# {'url': 'https://habr.com/ru/company/selectel/blog/506864/', 'is_parsed': True, 'raw_views_count': '39,3k', 'views_count': 39300}
# {'url': 'https://habr.com/ru/post/507160/', 'is_parsed': True, 'raw_views_count': '13,4k', 'views_count': 13400}
# {'url': 'https://habr.com/ru/company/sberbank/blog/507178/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/post/506956/', 'is_parsed': True, 'raw_views_count': '505', 'views_count': 505}
# {'url': 'https://habr.com/ru/post/507010/', 'is_parsed': True, 'raw_views_count': '6,6k', 'views_count': 6600}
# {'url': 'https://habr.com/ru/post/507032/', 'is_parsed': True, 'raw_views_count': '1,5k', 'views_count': 1500}
# {'url': 'https://habr.com/ru/company/yandex/blog/507028/', 'is_parsed': True, 'raw_views_count': '6,8k', 'views_count': 6800}
# {'url': 'https://habr.com/ru/post/507194/', 'is_parsed': True, 'raw_views_count': '4,9k', 'views_count': 4900}
# {'url': 'https://habr.com/ru/post/503764/', 'is_parsed': True, 'raw_views_count': '69,6k', 'views_count': 69600}
# {'url': 'https://habr.com/ru/company/cloud4y/blog/506760/', 'is_parsed': True, 'raw_views_count': '727', 'views_count': 727}
# {'url': 'https://habr.com/ru/company/banzai/blog/506390/', 'is_parsed': True, 'raw_views_count': '815', 'views_count': 815}
# {'url': 'https://habr.com/ru/company/kaspersky/blog/507158/', 'is_parsed': True, 'raw_views_count': '6,8k', 'views_count': 6800}
# {'url': 'https://habr.com/ru/post/506874/', 'is_parsed': True, 'raw_views_count': '9,1k', 'views_count': 9100}
# {'url': 'https://habr.com/ru/company/abbyy/blog/507214/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/post/506830/', 'is_parsed': True, 'raw_views_count': '1k', 'views_count': 1000}
# {'url': 'https://habr.com/ru/post/507174/', 'is_parsed': True, 'raw_views_count': '2,5k', 'views_count': 2500}
# {'url': 'https://habr.com/ru/company/pt/blog/506932/', 'is_parsed': True, 'raw_views_count': '1,3k', 'views_count': 1300}
# {'url': 'https://habr.com/ru/company/plesk/blog/507094/', 'is_parsed': True, 'raw_views_count': '3,5k', 'views_count': 3500}
# {'url': 'https://habr.com/ru/post/507112/', 'is_parsed': True, 'raw_views_count': '621', 'views_count': 621}
# {'url': 'https://habr.com/ru/company/ua-hosting/blog/506858/', 'is_parsed': True, 'raw_views_count': '3k', 'views_count': 3000}
# {'url': 'https://habr.com/ru/company/pixonic/blog/506768/', 'is_parsed': True, 'raw_views_count': '4,5k', 'views_count': 4500}
# {'url': 'https://habr.com/ru/company/innopolis/blog/506834/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/company/avito/blog/507202/', 'is_parsed': True, 'raw_views_count': '588', 'views_count': 588}
# {'url': 'https://habr.com/ru/company/pvs-studio/blog/507110/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/post/506954/', 'is_parsed': True, 'raw_views_count': '662', 'views_count': 662}
# {'url': 'https://habr.com/ru/company/itelma/blog/505376/', 'is_parsed': True, 'raw_views_count': '11,2k', 'views_count': 11200}
# {'url': 'https://habr.com/ru/company/netologyru/blog/507198/', 'is_parsed': True, 'raw_views_count': '220', 'views_count': 220}
# {'url': 'https://habr.com/ru/post/490412/', 'is_parsed': True, 'raw_views_count': '67,7k', 'views_count': 67700}
# {'url': 'https://habr.com/ru/company/advantech/blog/506678/', 'is_parsed': True, 'raw_views_count': '10,5k', 'views_count': 10500}
# {'url': 'https://habr.com/ru/company/abbyy/blog/506808/', 'is_parsed': True, 'raw_views_count': '7,3k', 'views_count': 7300}
# {'url': 'https://habr.com/ru/company/jugru/blog/506780/', 'is_parsed': True, 'raw_views_count': '569', 'views_count': 569}
# {'url': 'https://habr.com/ru/post/506892/', 'is_parsed': True, 'raw_views_count': '9,5k', 'views_count': 9500}
# {'url': 'https://habr.com/ru/post/506994/', 'is_parsed': True, 'raw_views_count': '4,3k', 'views_count': 4300}
# {'url': 'https://habr.com/ru/post/506912/', 'is_parsed': True, 'raw_views_count': '26k', 'views_count': 26000}
# {'url': 'https://habr.com/ru/company/google/blog/506992/', 'is_parsed': True, 'raw_views_count': '6k', 'views_count': 6000}
# {'url': 'https://habr.com/ru/company/edison/blog/507250/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/post/507030/', 'is_parsed': True, 'raw_views_count': '11,7k', 'views_count': 11700}
# {'url': 'https://habr.com/ru/company/otus/blog/506962/', 'is_parsed': True, 'raw_views_count': '2k', 'views_count': 2000}
# {'url': 'https://habr.com/ru/post/507050/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/company/group-ib/blog/504982/', 'is_parsed': True, 'raw_views_count': '7,1k', 'views_count': 7100}
# {'url': 'https://habr.com/ru/company/flant/blog/506948/', 'is_parsed': True, 'raw_views_count': '9,3k', 'views_count': 9300}
# {'url': 'https://habr.com/ru/company/billing/blog/506860/', 'is_parsed': True, 'raw_views_count': '134', 'views_count': 134}
# {'url': 'https://habr.com/ru/company/google/blog/507230/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/post/506980/', 'is_parsed': True, 'raw_views_count': '2,6k', 'views_count': 2600}
# {'url': 'https://habr.com/ru/company/sberbank/blog/506950/', 'is_parsed': True, 'raw_views_count': '10,7k', 'views_count': 10700}
# {'url': 'https://habr.com/ru/company/funcorp/blog/506770/', 'is_parsed': True, 'raw_views_count': '16,1k', 'views_count': 16100}
# {'url': 'https://habr.com/ru/post/507222/', 'is_parsed': True, 'raw_views_count': '65,6k', 'views_count': 65600}
# {'url': 'https://habr.com/ru/post/507206/', 'is_parsed': True, 'raw_views_count': '2,3k', 'views_count': 2300}
# {'url': 'https://habr.com/ru/company/digital-ecosystems/blog/507170/', 'is_parsed': True, 'raw_views_count': '9,2k', 'views_count': 9200}
# {'url': 'https://habr.com/ru/company/varonis/blog/507068/', 'is_parsed': True, 'raw_views_count': '2,3k', 'views_count': 2300}
# {'url': 'https://habr.com/ru/company/rosbank/blog/506866/', 'is_parsed': True, 'raw_views_count': '383', 'views_count': 383}
# {'url': 'https://habr.com/ru/company/socialquantum/blog/505886/', 'is_parsed': True, 'raw_views_count': '1,3k', 'views_count': 1300}
# {'url': 'https://habr.com/ru/post/489322/', 'is_parsed': True, 'raw_views_count': '785', 'views_count': 785}
# {'url': 'https://habr.com/ru/post/504120/', 'is_parsed': True, 'raw_views_count': '1,6k', 'views_count': 1600}
# {'url': 'https://habr.com/ru/company/globalsign/blog/506852/', 'is_parsed': True, 'raw_views_count': '10,6k', 'views_count': 10600}
# {'url': 'https://habr.com/ru/post/507074/', 'is_parsed': True, 'raw_views_count': '3,4k', 'views_count': 3400}
# {'url': 'https://habr.com/ru/company/otus/blog/506916/', 'is_parsed': True, 'raw_views_count': '1,8k', 'views_count': 1800}
# {'url': 'https://habr.com/ru/post/507182/', 'is_parsed': True, 'raw_views_count': '334', 'views_count': 334}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/507200/', 'is_parsed': True, 'raw_views_count': '3,2k', 'views_count': 3200}
# {'url': 'https://habr.com/ru/post/507204/', 'is_parsed': True, 'raw_views_count': '1,8k', 'views_count': 1800}
# {'url': 'https://habr.com/ru/company/click/blog/507066/', 'is_parsed': True, 'raw_views_count': '2,1k', 'views_count': 2100}
# {'url': 'https://habr.com/ru/post/507218/', 'is_parsed': True, 'raw_views_count': '1,5k', 'views_count': 1500}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/506880/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/post/506764/', 'is_parsed': True, 'raw_views_count': '1,6k', 'views_count': 1600}
# {'url': 'https://habr.com/ru/company/huawei/blog/507242/', 'is_parsed': True, 'raw_views_count': '7,8k', 'views_count': 7800}
# {'url': 'https://habr.com/ru/company/ruvds/blog/506890/', 'is_parsed': True, 'raw_views_count': '9,5k', 'views_count': 9500}
# {'url': 'https://habr.com/ru/company/dodopizzadev/blog/506378/', 'is_parsed': True, 'raw_views_count': '35,1k', 'views_count': 35100}
# {'url': 'https://habr.com/ru/post/506894/', 'is_parsed': True, 'raw_views_count': '13k', 'views_count': 13000}
# {'url': 'https://habr.com/ru/post/507034/', 'is_parsed': True, 'raw_views_count': '761', 'views_count': 761}
# {'url': 'https://habr.com/ru/post/506902/', 'is_parsed': True, 'raw_views_count': '9,1k', 'views_count': 9100}
# {'url': 'https://habr.com/ru/company/top3dshop/blog/506976/', 'is_parsed': True, 'raw_views_count': '467', 'views_count': 467}
# {'url': 'https://habr.com/ru/post/507022/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/company/otus/blog/507104/', 'is_parsed': True, 'raw_views_count': '2,9k', 'views_count': 2900}
# {'url': 'https://habr.com/ru/post/507124/', 'is_parsed': True, 'raw_views_count': '2k', 'views_count': 2000}
# {'url': 'https://habr.com/ru/company/vrike/blog/506928/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://habr.com/ru/company/mailru/blog/505908/', 'is_parsed': True, 'raw_views_count': '1,4k', 'views_count': 1400}
# {'url': 'https://habr.com/ru/company/skilline/blog/506522/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# {'url': 'https://habr.com/ru/post/507138/', 'is_parsed': True, 'raw_views_count': '1,9k', 'views_count': 1900}
# {'url': 'https://habr.com/ru/company/otus/blog/506964/', 'is_parsed': True, 'raw_views_count': '2,6k', 'views_count': 2600}
# {'url': 'https://habr.com/ru/company/hh/blog/507048/', 'is_parsed': True, 'raw_views_count': '3,6k', 'views_count': 3600}
# {'url': 'https://habr.com/ru/company/manychat/blog/507136/', 'is_parsed': True, 'raw_views_count': '8,6k', 'views_count': 8600}
# {'url': 'https://habr.com/ru/post/507190/', 'is_parsed': True, 'raw_views_count': '786', 'views_count': 786}
# {'url': 'https://habr.com/ru/post/506464/', 'is_parsed': True, 'raw_views_count': '1k', 'views_count': 1000}
# {'url': 'https://habr.com/ru/company/leader-id/blog/507042/', 'is_parsed': True, 'raw_views_count': '7,4k', 'views_count': 7400}
# {'url': 'https://habr.com/ru/post/507008/', 'is_parsed': True, 'raw_views_count': '781', 'views_count': 781}
# {'url': 'https://habr.com/ru/post/507084/', 'is_parsed': True, 'raw_views_count': '5,1k', 'views_count': 5100}
# {'url': 'https://habr.com/ru/company/skillfactory/blog/507052/', 'is_parsed': True, 'raw_views_count': '2,4k', 'views_count': 2400}
# CPU times: user 750 ms, sys: 431 ms, total: 1.18 s
# Wall time: 1min 49s

# %%
len(parse_results)
# Out:
# 430

# %% [markdown]
# 430 URLs
# CPU times: user 718 ms, sys: 295 ms, total: 1.01 s
# Wall time: 1min 41s
#
# 1 URL missed
# 'httas://habr.com/ru/comaany/skillfactory/blog/507058/'

# %% [markdown]
# **pikabu.ru**

# %%
pikabu_urls = filter_urls(valid_results, 'pikabu.ru')
pikabu_urls[:10]
# Out:
# ['https://pikabu.ru/story/moderator_vs_zombies_2177316',
#  'https://pikabu.ru/story/kak_ya_uznal_ob_izmene_ili_lyogkiy_sposob_brosit_shutit_7471791',
#  'https://pikabu.ru/story/budet_li_otvet_ot_kospleyshchikov_7366977',
#  'https://pikabu.ru/story/moskovskogo_gaishnika_zastavili_pisat_obyasnitelnuyu__on_ostanovil_zamglavyi_politsii_moskvyi_obezzhavshego_probku_po_vstrechke_7184069',
#  'https://pikabu.ru/story/mashkina_radost_6977120',
#  'https://pikabu.ru/story/spasibo_za_shaurmu_7519042',
#  'https://pikabu.ru/story/layk_esli_tozhe_ne_lyubish_rabotat_rukami_7508494',
#  'https://pikabu.ru/story/ne_smog_proyti_mimo_pervyikh_oduvanchikov_7398755',
#  'https://pikabu.ru/story/zhitel_saratova_mikhail_volkov_vyirastil_sosnovyiy_les_na_meste_svalki_tam_uzhe_zhivut_zaytsyi_i_fazanyi_6879615',
#  'https://pikabu.ru/story/khristiane_rossii_trebuyut_otmenit_statyu_148_uk_predpolagayushchuyu_ugolovnoe_presledovanie_sa_oskorblenie_chuvstv_veruyushchikh_7092228']

# %%
def get_pikabu_views_count(url):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    story_id = url.split('_')[-1]
    stat_url = f'https://d.pikabu.ru/stat/story/{story_id}'
    
    headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36'}
    req = requests.get(stat_url, headers=headers)
    
    try:
        req.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    stats_data = req.json()
    
    try:
        views_count = stats_data['data']['v']
    except AttributeError as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in pikabu_urls[:5]:
    parse_results = get_pikabu_views_count(url)
# Out:
# {'url': 'https://pikabu.ru/story/moderator_vs_zombies_2177316', 'is_parsed': True, 'raw_views_count': 4273, 'views_count': 4273}
# {'url': 'https://pikabu.ru/story/kak_ya_uznal_ob_izmene_ili_lyogkiy_sposob_brosit_shutit_7471791', 'is_parsed': True, 'raw_views_count': 713535, 'views_count': 713535}
# {'url': 'https://pikabu.ru/story/budet_li_otvet_ot_kospleyshchikov_7366977', 'is_parsed': True, 'raw_views_count': 617433, 'views_count': 617433}
# {'url': 'https://pikabu.ru/story/moskovskogo_gaishnika_zastavili_pisat_obyasnitelnuyu__on_ostanovil_zamglavyi_politsii_moskvyi_obezzhavshego_probku_po_vstrechke_7184069', 'is_parsed': True, 'raw_views_count': 76290, 'views_count': 76290}
# {'url': 'https://pikabu.ru/story/mashkina_radost_6977120', 'is_parsed': True, 'raw_views_count': 8103, 'views_count': 8103}
# CPU times: user 81.9 ms, sys: 0 ns, total: 81.9 ms
# Wall time: 6.5 s

# %%
# %%time
parse_results = list(map(get_pikabu_views_count, pikabu_urls[:5]))
# Out:
# {'url': 'https://pikabu.ru/story/moderator_vs_zombies_2177316', 'is_parsed': True, 'raw_views_count': 4248, 'views_count': 4248}
# {'url': 'https://pikabu.ru/story/kak_ya_uznal_ob_izmene_ili_lyogkiy_sposob_brosit_shutit_7471791', 'is_parsed': True, 'raw_views_count': 713420, 'views_count': 713420}
# {'url': 'https://pikabu.ru/story/budet_li_otvet_ot_kospleyshchikov_7366977', 'is_parsed': True, 'raw_views_count': 617406, 'views_count': 617406}
# {'url': 'https://pikabu.ru/story/moskovskogo_gaishnika_zastavili_pisat_obyasnitelnuyu__on_ostanovil_zamglavyi_politsii_moskvyi_obezzhavshego_probku_po_vstrechke_7184069', 'is_parsed': True, 'raw_views_count': 76230, 'views_count': 76230}
# {'url': 'https://pikabu.ru/story/mashkina_radost_6977120', 'is_parsed': True, 'raw_views_count': 8074, 'views_count': 8074}
# CPU times: user 66.7 ms, sys: 11.1 ms, total: 77.8 ms
# Wall time: 3.01 s

# %%
# %%time
with Pool() as P:
    parse_results = P.map(get_pikabu_views_count, pikabu_urls)
# Out:
# {'url': 'https://pikabu.ru/story/moderator_vs_zombies_2177316', 'is_parsed': True, 'raw_views_count': 4248, 'views_count': 4248}
# {'url': 'https://pikabu.ru/story/poborol_skromnost_6418931', 'is_parsed': True, 'raw_views_count': 4413, 'views_count': 4413}
# {'url': 'https://pikabu.ru/story/izbalovannost_pokupatelya_v_raznyikh_stranakh_6478602', 'is_parsed': True, 'raw_views_count': 2791, 'views_count': 2791}
# {'url': 'https://pikabu.ru/story/vnezapnaya_fotosessiya_4928301', 'is_parsed': True, 'raw_views_count': 4413, 'views_count': 4413}{'url': 'https://pikabu.ru/story/zhivyot_takoy_paren_6860996', 'is_parsed': True, 'raw_views_count': 8224, 'views_count': 8224}{'url': 'https://pikabu.ru/story/mne_strashno_6635809', 'is_parsed': True, 'raw_views_count': 3089, 'views_count': 3089}
#
#
# {'url': 'https://pikabu.ru/story/layk_esli_tozhe_ne_lyubish_rabotat_rukami_7508494', 'is_parsed': True, 'raw_views_count': 792303, 'views_count': 792303}
# {'url': 'https://pikabu.ru/story/obeshchannyiy_post_ochen_dlinnopost_5370470', 'is_parsed': True, 'raw_views_count': 3218, 'views_count': 3218}
# {'url': 'https://pikabu.ru/story/kak_ya_uznal_ob_izmene_ili_lyogkiy_sposob_brosit_shutit_7471791', 'is_parsed': True, 'raw_views_count': 713420, 'views_count': 713420}
# {'url': 'https://pikabu.ru/story/prilozhenie_burger_king_tayno_zapisyivaet_yekran_telefona_6021526', 'is_parsed': True, 'raw_views_count': 10535, 'views_count': 10535}
# {'url': 'https://pikabu.ru/story/deshyovyie_i_dorogie_batareyki_aaa_6797652', 'is_parsed': True, 'raw_views_count': 26234, 'views_count': 26234}
# {'url': 'https://pikabu.ru/story/styid_3022955', 'is_parsed': True, 'raw_views_count': 11986, 'views_count': 11986}
# {'url': 'https://pikabu.ru/story/pravilnyie_prioritetyi_6601915', 'is_parsed': True, 'raw_views_count': 6644, 'views_count': 6644}
# {'url': 'https://pikabu.ru/story/to_nelovkoe_chuvstvo_kogda_vse_govoryat_pro_kakogoto_kotika_3219427', 'is_parsed': True, 'raw_views_count': 8458, 'views_count': 8458}
# {'url': 'https://pikabu.ru/story/spravedlivost_7123953', 'is_parsed': True, 'raw_views_count': 7917, 'views_count': 7917}
# {'url': 'https://pikabu.ru/story/ne_ubirat_posledniy_prosmotrennyiy_post_v_prilozhenii_6308096', 'is_parsed': True, 'raw_views_count': 2435, 'views_count': 2435}
# {'url': 'https://pikabu.ru/story/v_zhizni_byivaet_vse__7489225', 'is_parsed': True, 'raw_views_count': 748864, 'views_count': 748864}
# {'url': 'https://pikabu.ru/story/obrashchenie_k_prezidentu_i_pravitelstvu_rossiyskoy_federatsii_6289432', 'is_parsed': True, 'raw_views_count': 5238, 'views_count': 5238}
# {'url': 'https://pikabu.ru/story/more_7041591', 'is_parsed': True, 'raw_views_count': 7217, 'views_count': 7217}
# {'url': 'https://pikabu.ru/story/tak_vot_v_chyom_delo_7405079', 'is_parsed': True, 'raw_views_count': 486308, 'views_count': 486308}
# {'url': 'https://pikabu.ru/story/sprosim_prezidenta_pro_khakhalevu_5947963', 'is_parsed': True, 'raw_views_count': 6318, 'views_count': 6318}
# {'url': 'https://pikabu.ru/story/byilo_dnyom_6627631', 'is_parsed': True, 'raw_views_count': 5786, 'views_count': 5786}
# {'url': 'https://pikabu.ru/story/badcomedian_obrashchenie_na_temu_sudov_shtrafov_i_tsenzuryi_6740346', 'is_parsed': True, 'raw_views_count': 28951, 'views_count': 28951}
# {'url': 'https://pikabu.ru/story/pochemu_peterburzhtsyi_protestovali_protiv_peredachi_rptsisaakievskogo_sobora_vot_pochemu_6378237', 'is_parsed': True, 'raw_views_count': 7435, 'views_count': 7435}
# {'url': 'https://pikabu.ru/story/podderzhim_evgena_3225970', 'is_parsed': True, 'raw_views_count': 6025, 'views_count': 6025}
# {'url': 'https://pikabu.ru/story/i__ironiya_7515923', 'is_parsed': True, 'raw_views_count': 769301, 'views_count': 769301}
# {'url': 'https://pikabu.ru/story/klyuchi_ot_shkatulki_pandoryi_nulevoy_patsient_yebolyi_6616546', 'is_parsed': True, 'raw_views_count': 7169, 'views_count': 7169}
# {'url': 'https://pikabu.ru/story/letom_2019_goda_ya_s_patsanami_kupil_zhiguli_chetverku_za_19_tyisyach_i_poekhal_na_ney_v_lissabon_7487954', 'is_parsed': True, 'raw_views_count': 936144, 'views_count': 936144}
# {'url': 'https://pikabu.ru/story/yura_i_dura_6584555', 'is_parsed': True, 'raw_views_count': 4464, 'views_count': 4464}
# {'url': 'https://pikabu.ru/story/anekdot_6992362', 'is_parsed': True, 'raw_views_count': 9060, 'views_count': 9060}
# {'url': 'https://pikabu.ru/story/anekdot_539100', 'is_parsed': True, 'raw_views_count': 2894, 'views_count': 2894}
# {'url': 'https://pikabu.ru/story/surovyie_budmi_vakhtovikov_6322059', 'is_parsed': True, 'raw_views_count': 4750, 'views_count': 4750}
# {'url': 'https://pikabu.ru/story/vot_vyi_vse_smeetes_nad_kianu_549882', 'is_parsed': True, 'raw_views_count': 4508, 'views_count': 4508}
# {'url': 'https://pikabu.ru/story/vneshnost__ne_glavnoeglavnoe_6586549', 'is_parsed': True, 'raw_views_count': 3828, 'views_count': 3828}
# {'url': 'https://pikabu.ru/story/slovo_ob_uchitelyakh_6607862', 'is_parsed': True, 'raw_views_count': 6766, 'views_count': 6766}
# {'url': 'https://pikabu.ru/story/snikers_razdora_6510197', 'is_parsed': True, 'raw_views_count': 3825, 'views_count': 3825}
# {'url': 'https://pikabu.ru/story/garik_kharlamov_pro_situatsiyu_sbadcomedian_6742339', 'is_parsed': True, 'raw_views_count': 3408, 'views_count': 3408}
# {'url': 'https://pikabu.ru/story/k_mame_dyadya_misha_prishyol_menya_gulyat_otpravili_v_tri_nochi_5490445', 'is_parsed': True, 'raw_views_count': 5529, 'views_count': 5529}
# {'url': 'https://pikabu.ru/story/badcomedian_i_isk_6778128', 'is_parsed': True, 'raw_views_count': 5964, 'views_count': 5964}
# {'url': 'https://pikabu.ru/story/opyat_obman_7179167', 'is_parsed': True, 'raw_views_count': 21870, 'views_count': 21870}
# {'url': 'https://pikabu.ru/story/proveryayte_ventilyatsiyu_7108375', 'is_parsed': True, 'raw_views_count': 6337, 'views_count': 6337}
# {'url': 'https://pikabu.ru/story/vyigonim_skorpiona_s_shapki_sayta_3262947', 'is_parsed': True, 'raw_views_count': 2350, 'views_count': 2350}
# {'url': 'https://pikabu.ru/story/rabota_na_kotoroy_stoit_rabotat_7409529', 'is_parsed': True, 'raw_views_count': 845824, 'views_count': 845824}
# {'url': 'https://pikabu.ru/story/kaznit_nelzya_pomilovat_7440226', 'is_parsed': True, 'raw_views_count': 507563, 'views_count': 507563}
# {'url': 'https://pikabu.ru/story/yevolyutsiya_kolyishka_dlya_kozyi_6137008', 'is_parsed': True, 'raw_views_count': 4179, 'views_count': 4179}
# {'url': 'https://pikabu.ru/story/shli_ubivat_kak_peterburzhets_zashchitilsya_ot_ugolovnikov_i_popal_pod_statyu_6446466', 'is_parsed': True, 'raw_views_count': 6872, 'views_count': 6872}
# {'url': 'https://pikabu.ru/story/kak_podnyat_nastroenie_sousem_neznakomyim_lyudyam__539157', 'is_parsed': True, 'raw_views_count': 4367, 'views_count': 4367}
# {'url': 'https://pikabu.ru/story/strannyiy_rabotodatel_6990040', 'is_parsed': True, 'raw_views_count': 5165, 'views_count': 5165}
# {'url': 'https://pikabu.ru/story/narodnaya_neft_7390403', 'is_parsed': True, 'raw_views_count': 671615, 'views_count': 671615}
# {'url': 'https://pikabu.ru/story/prosmotrennoe_6986238', 'is_parsed': True, 'raw_views_count': 9789, 'views_count': 9789}
# {'url': 'https://pikabu.ru/story/genyi_6306182', 'is_parsed': True, 'raw_views_count': 6040, 'views_count': 6040}
# {'url': 'https://pikabu.ru/story/v_4_goda_ya_zakhotela_stat_vrachom_v_30_let__ya_v_dekrete_iz_kotorogo_ne_vernus_6615487', 'is_parsed': True, 'raw_views_count': 12193, 'views_count': 12193}
# {'url': 'https://pikabu.ru/story/dnktest_vzglyad_so_storonyi_rebyonka_6853470', 'is_parsed': True, 'raw_views_count': 9621, 'views_count': 9621}
# {'url': 'https://pikabu.ru/story/pravilno_nafig_slushat_lavrova_6317068', 'is_parsed': True, 'raw_views_count': 6516, 'views_count': 6516}
# {'url': 'https://pikabu.ru/story/pridorozhnoe_kafe_5742804', 'is_parsed': True, 'raw_views_count': 3861, 'views_count': 3861}
# {'url': 'https://pikabu.ru/story/sayt_o_chinovnikakh_rf_7402649', 'is_parsed': True, 'raw_views_count': 730272, 'views_count': 730272}
# {'url': 'https://pikabu.ru/story/o_dvulichii_pikabu_na_primere_shashlyichnika_magomeda_5753834', 'is_parsed': True, 'raw_views_count': 12015, 'views_count': 12015}
# {'url': 'https://pikabu.ru/story/simpatishnaya_ona_7465459', 'is_parsed': True, 'raw_views_count': 654877, 'views_count': 654877}
# {'url': 'https://pikabu.ru/story/instruktsiya_pro_kolumbayn_i_teraktyi_6233081', 'is_parsed': True, 'raw_views_count': 3026, 'views_count': 3026}
# {'url': 'https://pikabu.ru/story/mozhno_li_vyirastit_perepelov_iz_yaits_kuplennyikh_v_ashane_6628140', 'is_parsed': True, 'raw_views_count': 8429, 'views_count': 8429}
# {'url': 'https://pikabu.ru/story/novogodnee_pozdravlenie_4722555', 'is_parsed': True, 'raw_views_count': 4807, 'views_count': 4807}
# {'url': 'https://pikabu.ru/stbry/true_stbry_3001448', 'is_parsed': True, 'raw_views_count': 12110, 'views_count': 12110}
# {'url': 'https://pikabu.ru/story/kak_obmanut_na_millionyi_rubley_popast_na_pervyiy_kanal_i_stat_uspeshnyim_7191916', 'is_parsed': True, 'raw_views_count': 87945, 'views_count': 87945}
# {'url': 'https://pikabu.ru/story/vizualiziruy_yeto_7167022', 'is_parsed': True, 'raw_views_count': 17536, 'views_count': 17536}
# {'url': 'https://pikabu.ru/story/7_let_yekonomii_7513209', 'is_parsed': True, 'raw_views_count': 642047, 'views_count': 642047}
# {'url': 'https://pikabu.ru/story/khoroshaya_familiya_6929729', 'is_parsed': True, 'raw_views_count': 3578, 'views_count': 3578}
# {'url': 'https://pikabu.ru/story/kak_ya_svoyu_kameru_popolzovatsya_na_paru_dney_daval_5307750', 'is_parsed': True, 'raw_views_count': 10097, 'views_count': 10097}
# {'url': 'https://pikabu.ru/story/khvatit_isterit_ostanovites_notrdam_spasen_dazhe_stulya_vnutri_ne_obgoreli_6646836', 'is_parsed': True, 'raw_views_count': 6134, 'views_count': 6134}
# {'url': 'https://pikabu.ru/story/zakryili_bolnichnyiy_7414822', 'is_parsed': True, 'raw_views_count': 735015, 'views_count': 735015}
# {'url': 'https://pikabu.ru/story/tagilskiy_metsenat_3147651', 'is_parsed': True, 'raw_views_count': 2392, 'views_count': 2392}
# {'url': 'https://pikabu.ru/story/katyukha_7424161', 'is_parsed': True, 'raw_views_count': 914961, 'views_count': 914961}{'url': 'https://pikabu.ru/story/sila_pikabu_vzyivayu_k_tebe_6218326', 'is_parsed': True, 'raw_views_count': 8451, 'views_count': 8451}
#
# {'url': 'https://pikabu.ru/story/blackstar_i_pabla_ukrali_moyu_fotografiyu_i_ispolzuyut_v_kommercheskikh_tselyakh_6875084', 'is_parsed': True, 'raw_views_count': 24050, 'views_count': 24050}
# {'url': 'https://pikabu.ru/story/samyie_legkie_dengi_7261376', 'is_parsed': True, 'raw_views_count': 819960, 'views_count': 819960}
# {'url': 'https://pikabu.ru/story/publichnyiy_prizyiv_izvinitsya_protoiereya_dmitriya_smirnova_7234315', 'is_parsed': True, 'raw_views_count': 375388, 'views_count': 375388}
# {'url': 'https://pikabu.ru/story/pro_beshenuyu_ku_na_bmv_6219595', 'is_parsed': True, 'raw_views_count': 19337, 'views_count': 19337}
# {'url': 'https://pikabu.ru/story/redditor_predlozhil_novyiy_kalendar_6866201', 'is_parsed': True, 'raw_views_count': 4102, 'views_count': 4102}
# {'url': 'https://pikabu.ru/story/otnoshenie_rukovodstva_7513987', 'is_parsed': True, 'raw_views_count': 705330, 'views_count': 705330}
# {'url': 'https://pikabu.ru/story/doshirak_nervno_kurit_v_storonke_7158196', 'is_parsed': True, 'raw_views_count': 11634, 'views_count': 11634}
# CPU times: user 257 ms, sys: 190 ms, total: 448 ms
# Wall time: 22.2 s

# %% [markdown]
# **pornhub.com**

# %%
pornhub_urls = filter_urls(valid_results, 'pornhub.com')
pornhub_urls[:10]
# Out:
# ['https://rt.pornhub.com/view_video.php?viewkey=ph5c66c76a1dc69',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5ed519f129f7d',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5ed77e4eb5c46',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5de9edb65e918',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5ed62c5f32084',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5e779536e48cf',
#  'https://rt.pornhub.com/view_video.php?viewtey=ph5e9da3f6d3f7d',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5ce1f627770af',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5eb312e5b7187',
#  'https://rt.pornhub.com/view_video.php?viewkey=ph5eb47970ac1ba']

# %%
def get_pornhub_views_count(url):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36'}
    req = requests.get(url, headers=headers)
    sleep(3)
    
    try:
        req.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    html_text = req.text
    soup = BeautifulSoup(html_text, 'lxml')
    
    try:
        views_count = soup.find('span', class_="count").text
    except AttributeError as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in pornhub_urls[:5]:
    parse_results = get_pornhub_views_count(url)
# Out:
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c66c76a1dc69', 'is_parsed': True, 'raw_views_count': '708 821', 'views_count': 708821}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed519f129f7d', 'is_parsed': True, 'raw_views_count': '249 413', 'views_count': 249413}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed77e4eb5c46', 'is_parsed': True, 'raw_views_count': '1 881 614', 'views_count': 1881614}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5de9edb65e918', 'is_parsed': True, 'raw_views_count': '182 736', 'views_count': 182736}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed62c5f32084', 'is_parsed': True, 'raw_views_count': '43 633', 'views_count': 43633}
# CPU times: user 1.27 s, sys: 39.7 ms, total: 1.31 s
# Wall time: 21.7 s

# %%
# %%time
parse_results = list(map(get_pornhub_views_count, pornhub_urls[:5]))
# Out:
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c66c76a1dc69', 'is_parsed': True, 'raw_views_count': '698 134', 'views_count': 698134}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed519f129f7d', 'is_parsed': True, 'raw_views_count': '245 474', 'views_count': 245474}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed77e4eb5c46', 'is_parsed': True, 'raw_views_count': '1 806 316', 'views_count': 1806316}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5de9edb65e918', 'is_parsed': True, 'raw_views_count': '181 704', 'views_count': 181704}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed62c5f32084', 'is_parsed': True, 'raw_views_count': '43 360', 'views_count': 43360}
# CPU times: user 1.48 s, sys: 18.6 ms, total: 1.5 s
# Wall time: 21.5 s

# %%
# %%time
with Pool() as P:
    parse_results = P.map(get_pornhub_views_count, pornhub_urls)
# Out:
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e7cdcdd158d7', 'is_parsed': False, 'error_code': 'element_not_found'}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ecd9cb0f1e2c', 'is_parsed': True, 'raw_views_count': '55 220', 'views_count': 55220}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed215da0b76a', 'is_parsed': True, 'raw_views_count': '325 212', 'views_count': 325212}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed1cfc0420c0', 'is_parsed': True, 'raw_views_count': '40 668', 'views_count': 40668}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5da790a858901', 'is_parsed': True, 'raw_views_count': '408 219', 'views_count': 408219}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c66c76a1dc69', 'is_parsed': True, 'raw_views_count': '698 134', 'views_count': 698134}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c673113cceb0', 'is_parsed': True, 'raw_views_count': '173 281', 'views_count': 173281}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ec2be2b7aaa0', 'is_parsed': True, 'raw_views_count': '1 558 950', 'views_count': 1558950}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e87e0fc57087', 'is_parsed': True, 'raw_views_count': '2 992', 'views_count': 2992}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed519f129f7d', 'is_parsed': True, 'raw_views_count': '245 474', 'views_count': 245474}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c7c28478b339', 'is_parsed': True, 'raw_views_count': '64 069', 'views_count': 64069}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5d289df943b89', 'is_parsed': True, 'raw_views_count': '2 707 308', 'views_count': 2707308}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e809990dfc5b', 'is_parsed': True, 'raw_views_count': '82 502', 'views_count': 82502}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e8f5e83d9d55', 'is_parsed': True, 'raw_views_count': '147 384', 'views_count': 147384}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5

# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e9816db3494f', 'is_parsed': True, 'raw_views_count': '48 736', 'views_count': 48736}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ea4fdd65d425', 'is_parsed': True, 'raw_views_count': '393 550', 'views_count': 393550}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c280ca0797c8', 'is_parsed': True, 'raw_views_count': '418 500', 'views_count': 418500}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5c170139c0990', 'is_parsed': True, 'raw_views_count': '129 208', 'views_count': 129208}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5xx3e3d2152fd', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://rt.pornhub.com/vinw_vidno.php?vinwkny=ph5nanf4036a22f', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e3d25615b3ab', 'is_parsed': True, 'raw_views_count': '59 105', 'views_count': 59105}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkeh=ph5eb6abd3b2db1', 'is_parsed': False, 'error_code': 'element_not_found'}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ec5a8f36ba61', 'is_parsed': True, 'raw_views_count': '172 540', 'views_count': 172540}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5b5625cb33670', 'is_parsed': True, 'raw_views_count': '90 319', 'views_count': 90319}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ea5d6853af77', 'is_parsed': False, 'error_code': 'element_not_found'}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e8bc066e5c7e', 'is_parsed': True, 'raw_views_count': '1 674 721', 'views_count': 1674721}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph568e95cec4737', 'is_parsed': True, 'raw_views_count': '13 722', 'views_count': 13722}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ec8ff56aa1e9', 'is_parsed': True, 'raw_views_count': '41 211', 'views_count': 41211}
# {'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5ed6212ce8856', 'is_parsed': True, 'raw_views_count': '236 252', 'views_count': 236252}{'url': 'https://rt.pornhub.com/view_video.php?viewkey=ph5e92211ec25da', 'is_parsed': True, 'raw_views_count': '269 342', 'views_count': 269342}

# %% [markdown]
# **rutube.ru**

# %%
rutube_urls = filter_urls(valid_results, 'rutube.ru')
rutube_urls[:10]
# Out:
# ['https://rutube.ru/video/8ba9b27f20c3a361bb02e91b7e74df05/',
#  'https://rutube.ru/video/fd0f357686152efe46d0c6a9eb9f8e8e/',
#  'https://rutube.ru/video/56868c5e19b6959a12748de745764414/',
#  'https://rutube.ru/video/4a625fc2a5af8295d0262cbcb2323177/',
#  'https://rutube.ru/video/89466964caf92d941cebe8c3b230889c/',
#  'https://rutube.ru/video/a4b850188e6b067eab43a2fe423c2d62/',
#  'https://rutube.ru/video/989a1a55f0ed4d0c429e55cc0a1c6891/',
#  'https://rutube.ru/video/0b26cbc38eaeb21f271643bf7108feb9/',
#  'https://rutube.ru/video/c4984e8092731ae81870684726b5f7ae/',
#  'https://rutube.ru/video/84a41a731d3090f67a3c7f91d32cf351/']

# %%
def get_rutube_views_count(url):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36'}
    req = requests.get(url, headers=headers)
#     sleep(3)
    
    try:
        req.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    html_text = req.text
    soup = BeautifulSoup(html_text, 'lxml')
    
    try:
        views_count = soup.find('span', class_="video-info-card__view-count").text
    except AttributeError as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in rutube_urls[:5]:
    parse_results = get_rutube_views_count(url)
# Out:
# {'url': 'https://rutube.ru/video/8ba9b27f20c3a361bb02e91b7e74df05/', 'is_parsed': True, 'raw_views_count': '22,327', 'views_count': 22327}
# {'url': 'https://rutube.ru/video/fd0f357686152efe46d0c6a9eb9f8e8e/', 'is_parsed': True, 'raw_views_count': '504', 'views_count': 504}
# {'url': 'https://rutube.ru/video/56868c5e19b6959a12748de745764414/', 'is_parsed': True, 'raw_views_count': '24,066', 'views_count': 24066}
# {'url': 'https://rutube.ru/video/4a625fc2a5af8295d0262cbcb2323177/', 'is_parsed': True, 'raw_views_count': '137', 'views_count': 137}
# {'url': 'https://rutube.ru/video/89466964caf92d941cebe8c3b230889c/', 'is_parsed': True, 'raw_views_count': '68', 'views_count': 68}
# CPU times: user 226 ms, sys: 9.2 ms, total: 236 ms
# Wall time: 25.7 s

# %%
# %%time
parse_results = list(map(get_rutube_views_count, rutube_urls[:5]))
# Out:
# {'url': 'https://rutube.ru/video/8ba9b27f20c3a361bb02e91b7e74df05/', 'is_parsed': True, 'raw_views_count': '22,327', 'views_count': 22327}
# {'url': 'https://rutube.ru/video/fd0f357686152efe46d0c6a9eb9f8e8e/', 'is_parsed': True, 'raw_views_count': '504', 'views_count': 504}
# {'url': 'https://rutube.ru/video/56868c5e19b6959a12748de745764414/', 'is_parsed': True, 'raw_views_count': '24,066', 'views_count': 24066}
# {'url': 'https://rutube.ru/video/4a625fc2a5af8295d0262cbcb2323177/', 'is_parsed': True, 'raw_views_count': '137', 'views_count': 137}
# {'url': 'https://rutube.ru/video/89466964caf92d941cebe8c3b230889c/', 'is_parsed': True, 'raw_views_count': '68', 'views_count': 68}
# CPU times: user 228 ms, sys: 2.84 ms, total: 231 ms
# Wall time: 6.05 s

# %%
# %%time
with Pool() as P:
    parse_results = P.map(get_rutube_views_count, rutube_urls)
# Out:
# {'url': 'https://rutube.ru/video/8ba9b27f20c3a361bb02e91b7e74df05/', 'is_parsed': True, 'raw_views_count': '22,327', 'views_count': 22327}
# {'url': 'https://rutube.ru/video/8b4ef6f3fe88fd37d7f68d0c5c49a0fe/', 'is_parsed': True, 'raw_views_count': '454', 'views_count': 454}
# {'url': 'https://rutube.ru/video/a331246d4228ae9cba9161c9aaf119be/', 'is_parsed': True, 'raw_views_count': '906', 'views_count': 906}
# {'url': 'https://rutube.ru/video/1128f7a0eb3a47b832fd0f641498b0b0/', 'is_parsed': True, 'raw_views_count': '414', 'views_count': 414}
# {'url': 'https://rutube.ru/video/360b3ac638c7179122c0f09e37d349da/', 'is_parsed': True, 'raw_views_count': '21,933', 'views_count': 21933}
# {'url': 'https://rutube.ru/video/54612a5d3a5abcaa382f8c693b261600/', 'is_parsed': True, 'raw_views_count': '200', 'views_count': 200}
# {'url': 'https://rutube.ru/video/4ad7e599a118c119ca515d6ebafbc4d4/', 'is_parsed': True, 'raw_views_count': '60', 'views_count': 60}
# {'url': 'https://rutube.ru/video/9c7957c02e6a22c7909c3369bb3e6174/', 'is_parsed': True, 'raw_views_count': '97', 'views_count': 97}
', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://rutube.ru/video/a8bbb396c8dc8f2279a2190f7a9ce7e0/', 'is_parsed': True, 'raw_views_count': '21,438', 'views_count': 21438}
# {'url': 'https://rutube.ru/video/04a769d9975b8fc7e37d4546fad8b3eb/', 'is_parsed': True, 'raw_views_count': '19,033', 'views_count': 19033}
# {'url': 'https://rutube.ru/video/06f7b6bde5fd6a4384fbda5d44f9b161/', 'is_parsed': False, 'error_code': 'element_not_found'}
# {'url': 'https://rutube.ru/video/ee1852100b510bb958f67574481f8879/', 'is_parsed': True, 'raw_views_count': '20,338', 'views_count': 20338}
# {'url': 'https://rutube.ru/video/2718813dc050c0aedbe53b6a0cc867a1/', 'is_parsed': True, 'raw_views_count': '20,321', 'views_count': 20321}
# {'url': 'https://rutube.ru/video/68e8e69570e2ad5247baee4317eb6f12/', 'is_parsed': True, 'raw_views_count': '559', 'views_count': 559}
# {'url': 'https://rutube.ru/video/95b5fb50c06a79f1061dffd35b99d190/', 'is_parsed': True, 'raw_views_count': '200,248', 'views_count': 200248}
# {'url': 'https://rutube.ru/video/47eb3b0abc8fc8ea5216352e6a04c968/', 'is_parsed': True, 'raw_views_count': '57', 'views_count': 57}
# {'url': 'https://rutube.ru/video/0d67f4e0c226c83505b852f7f979ee8d/', 'is_parsed': True, 'raw_views_count': '333', 'views_count': 333}
# {'url': 'https://rutube.ru/video/0de88da646561c52203b7d0752701429/', 'is_parsed': True, 'raw_views_count': '97', 'views_count': 97}
# {'url': 'https://rutube.ru/vddeo/38fe90ef57b50093a9ec75fe610d4e49/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://rutube.ru/video/5f083e29acec2b637e1a7fa171367e30/', 'is_parsed': True, 'raw_views_count': '146', 'views_count': 146}
# {'url': 'https://rutube.ru/video/5482b652b0a2ce57c3da5f41214ad8be/', 'is_parsed': True, 'raw_views_count': '62', 'views_count': 62}
# {'url': 'https://rutube.ru/video/36d0f8b60718456f45ae7e5087e7ac63/', 'is_parsed': True, 'raw_views_count': '19,874', 'views_count': 19874}
# {'url': 'https://rutube.ru/video/82ff93fb1b5607aa340ad069e282d292/', 'is_parsed': True, 'raw_views_count': '20', 'views_count': 20}
# CPU times: user 483 ms, sys: 289 ms, total: 773 ms
# Wall time: 1min 34s

# %% [markdown]
# **vimeo.com**

# %% [markdown]
# https://vimeo.com/91371852?action=load_stat_counts

# %%
vimeo_urls = filter_urls(valid_results, 'vimeo.com')
vimeo_urls[:10]
# Out:
# ['https://vimeo.com/91371852',
#  'https://vimeo.com/4085044',
#  'https://vimeo.com/33717000',
#  'https://vimeo.com/288392170',
#  'https://vimeo.com/200162057',
#  'https://vimeo.com/259970807',
#  'https://vimeo.com/54521591',
#  'https://vimeo.com/288392170',
#  'https://vimeo.com/181117661',
#  'https://vimeo.com/105155012']

# %%
def get_vimeo_views_count(url):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest'
    }
    
    url = f'{url}?action=load_stat_counts'
    req = requests.get(url, headers=headers)
    sleep(1)
    
    try:
        req.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    html_text = req.text
    soup = BeautifulSoup(html_text, 'lxml')
    
    try:
        views_count = req.json()['total_plays']['raw']
    except (AttributeError, KeyError, IndexError) as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in vimeo_urls[:5]:
    parse_results = get_vimeo_views_count(url)
# Out:
# {'url': 'https://vimeo.com/91371852', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/4085044', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/33717000', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/288392170', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/200162057', 'is_parsed': False, 'error_code': '403_forbidden'}
# CPU times: user 64.5 ms, sys: 12.3 ms, total: 76.8 ms
# Wall time: 5.38 s

# %%
# %%time
parse_results = list(map(get_vimeo_views_count, vimeo_urls[:5]))
# Out:
# {'url': 'https://vimeo.com/91371852', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/4085044', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/33717000', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/288392170', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/200162057', 'is_parsed': False, 'error_code': '403_forbidden'}
# CPU times: user 66.6 ms, sys: 4.58 ms, total: 71.2 ms
# Wall time: 384 ms

# %%
# %%time
with Pool() as P:
    parse_results = P.map(get_vimeo_views_count, vimeo_urls)
# Out:
# {'url': 'https://vimeo.com/25464003', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/59139723', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/91371852', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/151359255', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/39668547', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/105155012', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/25630712', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/100811895', 'is_parsed': False, 'error_code': '403_forbidden'}
#
#
#
#
#
#
#
# {'url': 'https://vimeo.com/172343600', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/55760922', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/4085044', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/129420469', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/292255593', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/117272042', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/145804885', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/11094292', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/42042473', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/19958940', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/96553319', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/125583827', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/139505310', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/33717000', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/84569117', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/106871589', 'is_parsed': False, 'error_code': '403_forbidden'}
#
#
# {'url': 'https://vimeo.com/34607698', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/3896443', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/270255446', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/414454130', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/288392170', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/122970508', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/267633432', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/52420812', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/33687095', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/174315219', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/353110008', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/27046295', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/200162057', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/146882062', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/248321712', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/198049687', 'is_parsed': False, 'error_code': '403_forbidden'}
#
#
#
# {'url': 'https://vimeo.com/317823527', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/610126814', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/204253827', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/259970807', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/301334295', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/270960322', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/18725817', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/163997377', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/15117193', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/35445287', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/32890104', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/54521591', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/61527383', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/371504100', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/122107800', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/85254632', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/197494710', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/81977376', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/114392377', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/184352515', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/288392170', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/295613162', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/89619479', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/26370076', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/131735627', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/150793153', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/176843190', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/181117661', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/326073569', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/209294413', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/26811028', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/265464974', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/927536420', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/55996808', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/9492810', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/190580407', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/295613162', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/157729549', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/56735188', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/71616190', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/360325492', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/137129953', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/194351968', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/156845281', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/330251941', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/82090343', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/54521591', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/334243768', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/94961900', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/376333377', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/394436926', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/379679308', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/87634300', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/78995632', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/188195040', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/190851514', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/280090310', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/281642324', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com/124160618', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/329178491', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/147441497', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/16390759', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/162393332', 'is_parsed': False, 'error_code': '403_forbidden'}
#
#
# {'url': 'https://vimeo.com/45579023', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://vimeo.com/364884530', 'is_parsed': False, 'error_code': '403_forbidden'}{'url': 'https://vimeo.com/96283218', 'is_parsed': False, 'error_code': '403_forbidden'}
#
# {'url': 'https://vimeo.com
        scripts = soup.find_all('script')
        scripts_str = list(map(lambda x: x.string, scripts))
        count_scripts_str = list(filter(lambda x: x is not None, scripts_str))
        count_scripts_str = list(filter(lambda x: 'viewCount' in x, count_scripts_str))
        
        pattern = re.compile(r'viewCount[\\]{,1}":[\\]{,1}"(\d+)')
        
        views_count = re.findall(pattern, count_scripts_str[0])[0]
    except (AttributeError, IndexError) as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    
    print(parse_results)
    
    return parse_results

# %%
# %%time
for url in youtube_urls[:5]:
    parse_results = get_youtube_views_count(url)
# Out:
# {'url': 'https://www.youtube.com/watch?v=vvdLLbhxwDA', 'is_parsed': True, 'raw_views_count': '223440', 'views_count': 223440}
# {'url': 'https://www.youtube.com/watch?v=l5aw6LHt9iI', 'is_parsed': True, 'raw_views_count': '349513', 'views_count': 349513}
# {'url': 'https://www.youtube.com/watch?v=U4kyT-wwEi0', 'is_parsed': True, 'raw_views_count': '367990', 'views_count': 367990}
# {'url': 'https://www.youtube.com/watch?v=-UuXFqXp7P4', 'is_parsed': True, 'raw_views_count': '54241', 'views_count': 54241}
# {'url': 'https://www.youtube.com/watch?v=wW9trOm303g', 'is_parsed': True, 'raw_views_count': '64803', 'views_count': 64803}
# CPU times: user 222 ms, sys: 27.2 ms, total: 249 ms
# Wall time: 9.27 s

# %%
# %%time
parse_results = list(map(get_youtube_views_count, youtube_urls[:5]))
# Out:
# {'url': 'https://www.youtube.com/watch?v=vvdLLbhxwDA', 'is_parsed': True, 'raw_views_count': '223440', 'views_count': 223440}
# {'url': 'https://www.youtube.com/watch?v=l5aw6LHt9iI', 'is_parsed': True, 'raw_views_count': '349459', 'views_count': 349459}
# {'url': 'https://www.youtube.com/watch?v=U4kyT-wwEi0', 'is_parsed': True, 'raw_views_count': '367966', 'views_count': 367966}
# {'url': 'https://www.youtube.com/watch?v=-UuXFqXp7P4', 'is_parsed': True, 'raw_views_count': '54241', 'views_count': 54241}
# {'url': 'https://www.youtube.com/watch?v=wW9trOm303g', 'is_parsed': True, 'raw_views_count': '64803', 'views_count': 64803}
# CPU times: user 240 ms, sys: 0 ns, total: 240 ms
# Wall time: 4.3 s

# %% [raw]
# %%time
# parse_results = list(map(get_youtube_views_count, youtube_urls))

# %% [raw]
# %%time
# with Pool(1) as P:
#     parse_results = P.map(get_youtube_views_count, youtube_urls)

# %% [markdown]
# **Common functionality**

# %% [raw]
# ['habr.com',
#  'pikabu.ru',
#  'rt.pornhub.com',
#  'rutube.ru',
#  'vimeo.com',
#  'www.youtube.com']

# %%
def parse_habr_views_count(response):
    html_text = response.text
    soup = BeautifulSoup(html_text, 'lxml')
    views_count = soup.find('span', class_="post-stats__views-count").text
    return views_count

# %%
def prepare_pikabu_request(url, headers):
    story_id = url.split('_')[-1]
    stat_url = f'https://d.pikabu.ru/stat/story/{story_id}'
    return stat_url, headers

# %%
def parse_pikabu_views_count(response):
    stats_data = response.json()
    views_count = stats_data['data']['v']
    return views_count

# %%
def parse_pornhub_views_count(response):
    html_text = response.text
    soup = BeautifulSoup(html_text, 'lxml')
    views_count = soup.find('span', class_="count").text
    return views_count

# %%
def parse_rutube_views_count(response):
    html_text = response.text
    soup = BeautifulSoup(html_text, 'lxml')
    views_count = soup.find('span', class_="video-info-card__view-count").text
    return views_count

# %%
def prepare_vimeo_request(url, headers):
    stat_url = f'{url}?action=load_stat_counts'
    headers['x-requested-with'] = 'XMLHttpRequest'
    return stat_url, headers

# %%
def parse_vimeo_views_count(response):
    json_data = response.json()
    views_count = json_data['total_plays']['raw']
    return views_count

# %%
def parse_youtube_views_count(response):
    html_text = response.text
    soup = BeautifulSoup(html_text, 'lxml')
    
    scripts = soup.find_all('script')
    scripts_str = list(map(lambda x: x.string, scripts))
    count_scripts_str = list(filter(lambda x: x is not None, scripts_str))
    count_scripts_str = list(filter(lambda x: 'viewCount' in x, count_scripts_str))
    
    pattern = re.compile(r'viewCount[\\]{,1}":[\\]{,1}"(\d+)')
    views_count = re.findall(pattern, count_scripts_str[0])[0]
    return views_count

# %%
DOMAIN_PARSERS = {
    'habr.com': {
        'parse': parse_habr_views_count,
    },
    'pikabu.ru': {
        'parse': parse_pikabu_views_count,
        'prepare_request': prepare_pikabu_request
    },
    'pornhub.com': {
        'parse': parse_pornhub_views_count
    },
    'rutube.ru': {
        'parse': parse_rutube_views_count
    },
    'vimeo.com': {
        'parse': parse_vimeo_views_count,
        'prepare_request': prepare_vimeo_request
    },
    'youtube.com': {
        'parse': parse_youtube_views_count
    }
}

DOMAINS = list(DOMAIN_PARSERS.keys())

# %%
def parse_views_count(response, domain):
    return DOMAIN_PARSERS[domain]['parse'](response)

# %%
def get_domain(url, levels=2):
    netloc = urlparse(url).netloc
    domain = '.'.join(netloc.split('.')[-levels:]).lower()
    return domain

# %%
def get_views_count(url, sleep_time=1):
    parse_results = {}
    parse_results['url'] = url
    parse_results['is_parsed'] = False
    
    domain = get_domain(url)
    prepare_request = DOMAIN_PARSERS[domain].get('prepare_request')
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.95 Safari/537.36'}
    
    if prepare_request is not None:
        url, headers = prepare_request(url, headers)
        
    response = requests.get(url, headers=headers)
    sleep(sleep_time)
    
    try:
        response.raise_for_status()
    except HTTPError as e:
        status_code = str(e.response.status_code)
        reason = '_'.join(e.response.reason.lower().split())
        error_code = "_".join([status_code, reason])
        parse_results['error_code'] = error_code
        print(parse_results)
        return parse_results
    
    try:
        views_count = parse_views_count(response, domain)
    except (AttributeError, IndexError, KeyError) as e:
        parse_results['error_code'] = f'element_not_found'
        print(parse_results)
        return parse_results
    
    parse_results['is_parsed'] = True
    parse_results['raw_views_count'] = views_count
    parse_results['views_count'] = clean_views_count(views_count)
    print(parse_results)
    
    return parse_results

# %% [raw]
# urls = [
#     'https://habr.com/ru/company/wrike/blog/506928/',
#     'https://pikabu.ru/story/kak_ya_uznal_ob_izmene_ili_lyogkiy_sposob_brosit_shutit_7471791',
#     'https://rt.pornhub.com/view_video.php?viewkey=ph5c66c76a1dc69',
#     'https://rutube.ru/video/8ba9b27f20c3a361bb02e91b7e74df05/',
# ]
#
# for url in urls:
#     get_views_count(url, sleep_time=1)

# %%
DOMAINS = [
    'habr.com',
    'pikabu.ru',
    'rt.pornhub.com',
    'rutube.ru',
    'vimeo.com',
    'www.youtube.com'
]

# %%
def get_domain_counts(valid_results, domain):
    domain_urls = filter_urls(valid_results, domain)
    return list(map(get_views_count, domain_urls))

# %%
args = [(valid_results[:10], domain) for domain in DOMAINS]
cpu_count = len(DOMAINS)

with Pool(cpu_count) as p:
    domain_results = p.starmap(get_domain_counts, args)
    
#domain_results
# Out:
# {'url': 'https://vimeo.com/91371852', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://habr.com/ru/company/wrike/blog/506928/', 'is_parsed': True, 'raw_views_count': '532', 'views_count': 532}
# {'url': 'https://www.youtube.com/watch?v=vvdLLbhxwDA', 'is_parsed': True, 'raw_views_count': '223440', 'views_count': 223440}
# {'url': 'https://vimeo.com/4085044', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://habr.com/ru/post/193844/', 'is_parsed': False, 'error_code': '404_not_found'}
# {'url': 'https://vimeo.com/33717000', 'is_parsed': False, 'error_code': '403_forbidden'}
# {'url': 'https://www.youtube.com/watch?v=l5aw6LHt9iI', 'is_parsed': True, 'raw_views_count': '349529', 'views_count': 349529}
# {'url': 'https://www.youtube.com/watch?v=U4kyT-wwEi0', 'is_parsed': True, 'raw_views_count': '367990', 'views_count': 367990}
# {'url': 'https://www.youtube.com/watch?v=-UuXFqXp7P4', 'is_parsed': True, 'raw_views_count': '54241', 'views_count': 54241}
# {'url': 'https://www.youtube.com/watch?v=wW9trOm303g', 'is_parsed': True, 'raw_views_count': '64851', 'views_count': 64851}

# %%
from itertools import chain

parse_results = list(chain(*domain_results))
parse_results
# Out:
# [{'url': 'https://habr.com/ru/company/wrike/blog/506928/',
#   'is_parsed': True,
#   'raw_views_count': '532',
#   'views_count': 532},
#  {'url': 'https://habr.com/ru/post/193844/',
#   'is_parsed': False,
#   'error_code': '404_not_found'},
#  {'url': 'https://vimeo.com/91371852',
#   'is_parsed': False,
#   'error_code': '403_forbidden'},
#  {'url': 'https://vimeo.com/4085044',
#   'is_parsed': False,
#   'error_code': '403_forbidden'},
#  {'url': 'https://vimeo.com/33717000',
#   'is_parsed': False,
#   'error_code': '403_forbidden'},
#  {'url': 'https://www.youtube.com/watch?v=vvdLLbhxwDA',
#   'is_parsed': True,
#   'raw_views_count': '223440',
#   'views_count': 223440},
#  {'url': 'https://www.youtube.com/watch?v=l5aw6LHt9iI',
#   'is_parsed': True,
#   'raw_views_count': '349529',
#   'views_count': 349529},
#  {'url': 'https://www.youtube.com/watch?v=U4kyT-wwEi0',
#   'is_parsed': True,
#   'raw_views_count': '367990',
#   'views_count': 367990},
#  {'url': 'https://www.youtube.com/watch?v=-UuXFqXp7P4',
#   'is_parsed': True,
#   'raw_views_count': '54241',
#   'views_count': 54241},
#  {'url': 'https://www.youtube.com/watch?v=wW9trOm303g',
#   'is_parsed': True,
#   'raw_views_count': '64851',
#   'views_count': 64851}]
